# %% [markdown]
# <a href="https://cognitiveclass.ai"><img src = "https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width = 400> </a>
#
# <h1 align=center><font size = 5>Regression Models with Keras</font></h1>

# %% [markdown]
# ## Introduction

# %% [markdown]
# As we discussed in the videos, despite the popularity of more powerful libraries such as PyToch and TensorFlow, they are not easy to use and have a steep learning curve. So, for people who are just starting to learn deep learning, there is no better library to use other than the Keras library.
#
# Keras is a high-level API for building deep learning models. It has gained favor for its ease of use and syntactic simplicity facilitating fast development. As you will see in this lab and the other labs in this course, building a very complex deep learning network can be achieved with Keras with only few lines of code. You will appreciate Keras even more, once you learn how to build deep models using PyTorch and TensorFlow in the other courses.
#
# So, in this lab, you will learn how to use the Keras library to build a regression model.

# %% [markdown]
# ## Table of Contents
#
# <div class="alert alert-block alert-info" style="margin-top: 20px">
#
# <font size = 3>
#
# 1. <a href="#item31">Download and Clean Dataset</a>
# 2. <a href="#item32">Import Keras</a>
# 3. <a href="#item33">Build a Neural Network</a>
# 4. <a href="#item34">Train and Test the Network</a>
#
# </font>
# </div>

# %% [markdown]
# <a id="item31"></a>

# %% [markdown]
# ## Download and Clean Dataset

# %% [markdown]
# Let's start by importing the <em>pandas</em> and the Numpy libraries.

# %%
from __future__ import absolute_import, division, print_function, unicode_literals
import sys

import pandas as pd
import numpy as np
import tensorflow as tf
tf.debugging.set_log_device_placement(True)


from datetime import datetime

# %% [markdown]
# We will be playing around with the same dataset that we used in the videos.
#
# <strong>The dataset is about the compressive strength of different samples of concrete based on the volumes of the different ingredients that were used to make them. Ingredients include:</strong>
#
# <strong>1. Cement</strong>
#
# <strong>2. Blast Furnace Slag</strong>
#
# <strong>3. Fly Ash</strong>
#
# <strong>4. Water</strong>
#
# <strong>5. Superplasticizer</strong>
#
# <strong>6. Coarse Aggregate</strong>
#
# <strong>7. Fine Aggregate</strong>

# %%
device_name = "gpu"  # Choose device from cmd line. Options: gpu or cpu

if device_name == "gpu":

    device_name = "/gpu:0"

else:

    device_name = "/cpu:0"

# %% [markdown]
# Let's download the data and read it into a <em>pandas</em> dataframe.

# %%
concrete_data = pd.read_csv('https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DL0101EN/labs/data/concrete_data.csv')
concrete_data.head()
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age  Strength
# 0            1040.0           676.0   28     79.99
# 1            1055.0           676.0   28     61.89
# 2             932.0           594.0  270     40.27
# 3             932.0           594.0  365     41.05
# 4             978.4           825.5  360     44.30

# %% [markdown]
# So the first concrete sample has 540 cubic meter of cement, 0 cubic meter of blast furnace slag, 0 cubic meter of fly ash, 162 cubic meter of water, 2.5 cubic meter of superplaticizer, 1040 cubic meter of coarse aggregate, 676 cubic meter of fine aggregate. Such a concrete mix which is 28 days old, has a compressive strength of 79.99 MPa.

# %% [markdown]
# #### Let's check how many data points we have.

# %%
concrete_data.shape
# Out:
# (1030, 9)

# %% [markdown]
# So, there are approximately 1000 samples to train our model on. Because of the few samples, we have to be careful not to overfit the training data.

# %% [markdown]
# Let's check the dataset for any missing values.

# %%
concrete_data.describe()
# Out:
#             Cement  Blast Furnace Slag      Fly Ash        Water  \
# count  1030.000000         1030.000000  1030.000000  1030.000000
# mean    281.167864           73.895825    54.188350   181.567282
# std     104.506364           86.279342    63.997004    21.354219
# min     102.000000            0.000000     0.000000   121.800000
# 25%     192.375000            0.000000     0.000000   164.900000
# 50%     272.900000           22.000000     0.000000   185.000000
# 75%     350.000000          142.950000   118.300000   192.000000
# max     540.000000          359.400000   200.100000   247.000000
#
#        Superplasticizer  Coarse Aggregate  Fine Aggregate          Age  \
# count       1030.000000       1030.000000     1030.000000  1030.000000
# mean           6.204660        972.918932      773.580485    45.662136
# std            5.973841         77.753954       80.175980    63.169912
# min            0.000000        801.000000      594.000000     1.000000
# 25%            0.000000        932.000000      730.950000     7.000000
# 50%            6.400000        968.000000      779.500000    28.000000
# 75%           10.200000       1029.400000      824.000000    56.000000
# max           32.200000       1145.000000      992.600000   365.000000
#
#           Strength
# count  1030.000000
# mean     35.817961
# std      16.705742
# min       2.330000
# 25%      23.710000
# 50%      34.445000
# 75%      46.135000
# max      82.600000

# %%
concrete_data.isnull().sum()
# Out:
# Cement                0
# Blast Furnace Slag    0
# Fly Ash               0
# Water                 0
# Superplasticizer      0
# Coarse Aggregate      0
# Fine Aggregate        0
# Age                   0
# Strength              0
# dtype: int64

# %% [markdown]
# The data looks very clean and is ready to be used to build our model.

# %% [markdown]
# #### Split data into predictors and target

# %% [markdown]
# The target variable in this problem is the concrete sample strength. Therefore, our predictors will be all the other columns.

# %%
concrete_data_columns = concrete_data.columns

predictors = concrete_data[concrete_data_columns[concrete_data_columns != 'Strength']] # all columns except Strength
target = concrete_data['Strength'] # Strength column

# %% [markdown]
# <a id="item2"></a>

# %% [markdown]
# Let's do a quick sanity check of the predictors and the target dataframes.

# %%
predictors.head()
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age
# 0            1040.0           676.0   28
# 1            1055.0           676.0   28
# 2             932.0           594.0  270
# 3             932.0           594.0  365
# 4             978.4           825.5  360

# %%
target.head()
# Out:
# 0    79.99
# 1    61.89
# 2    40.27
# 3    41.05
# 4    44.30
# Name: Strength, dtype: float64

# %% [markdown]
# Finally, the last step is to normalize the data by substracting the mean and dividing by the standard deviation.

# %%
predictors_norm = (predictors - predictors.mean()) / predictors.std()
predictors_norm.head()
# Out:
#      Cement  Blast Furnace Slag   Fly Ash     Water  Superplasticizer  \
# 0  2.476712           -0.856472 -0.846733 -0.916319         -0.620147
# 1  2.476712           -0.856472 -0.846733 -0.916319         -0.620147
# 2  0.491187            0.795140 -0.846733  2.174405         -1.038638
# 3  0.491187            0.795140 -0.846733  2.174405         -1.038638
# 4 -0.790075            0.678079 -0.846733  0.488555         -1.038638
#
#    Coarse Aggregate  Fine Aggregate       Age
# 0          0.862735       -1.217079 -0.279597
# 1          1.055651       -1.217079 -0.279597
# 2         -0.526262       -2.239829  3.551340
# 3         -0.526262       -2.239829  5.055221
# 4          0.070492        0.647569  4.976069

# %% [markdown]
# Let's save the number of predictors to *n_cols* since we will need this number when building our network.

# %%
n_cols = predictors_norm.shape[1] # number of predictors

# %% [markdown]
# <a id="item1"></a>

# %% [markdown]
# <a id='item32'></a>

# %% [markdown]
# ## Import Keras

# %% [markdown]
# Recall from the videos that Keras normally runs on top of a low-level library such as TensorFlow. This means that to be able to use the Keras library, you will have to install TensorFlow first and when you import the Keras library, it will be explicitly displayed what backend was used to install the Keras library. In CC Labs, we used TensorFlow as the backend to install Keras, so it should clearly print that when we import Keras.

# %% [markdown]
# #### Let's go ahead and import the Keras library

# %%
import keras
# Out:
# Using TensorFlow backend.

# %% [markdown]
# As you can see, the TensorFlow backend was used to install the Keras library.

# %% [markdown]
# Let's import the rest of the packages from the Keras library that we will need to build our regressoin model.

# %%
from keras.models import Sequential
from keras.layers import Dense

# %% [markdown]
# <a id='item33'></a>

# %% [markdown]
# ## Build a Neural Network

# %% [markdown]
# Let's define a function that defines our regression model for us so that we can conveniently call it to create our model.

# %%
# define regression model
def regression_model():
    # create model
    model = Sequential()
    model.add(Dense(50, activation='relu', input_shape=(n_cols,)))
    model.add(Dense(50, activation='relu'))
    model.add(Dense(50, activation='relu'))
    model.add(Dense(1))
    
    # compile model
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

# %% [markdown]
# The above function create a model that has two hidden layers, each of 50 hidden units.

# %% [markdown]
# <a id="item4"></a>

# %% [markdown]
# <a id='item34'></a>

# %% [markdown]
# ## Train and Test the Network

# %% [markdown]
# Let's call the function now to create our model.

# %%
# build the model
me_arran_squared_error_arr = []

from sklearn.model_selection import train_test_split
with tf.device(device_name):
    for i in range(50):
        X_train, X_test, y_train, y_test = train_test_split(predictors_norm, target, test_size = 0.3, random_state = 5)
        model = regression_model()
        # fit model
        model.fit(X_train, y_train, batch_size = 100, epochs=100, verbose=2)
        y_pred = model.predict(X_test)

        me_arran_squared_error_arr.append( model.evaluate(X_test, y_test, verbose=0))
# Out:
# Executing op RandomUniform in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Sub in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Mul in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Add in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarIsInitializedOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op LogicalNot in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Assert in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Fill in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op RandomUniform in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op RandomUniform in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op RandomUniform in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Reshape in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Epoch 1/100
# Executing op __inference_keras_scratch_graph_1051 in device /job:localhost/replica:0/task:0/device:GPU:0
#  - 1s - loss: 1572.2095
# Epoch 2/100
#  - 0s - loss: 1536.9046
# Epoch 3/100
#  - 0s - loss: 1490.5501
# Epoch 4/100
#  - 0s - loss: 1419.4511
# Epoch 5/100
#  - 0s - loss: 1308.7073
# Epoch 6/100
#  - 0s - loss: 1142.7003
# Epoch 7/100
#  - 0s - loss: 911.1318
# Epoch 8/100
#  - 0s - loss: 634.8780
# Epoch 9/100
#  - 0s - loss: 378.8351
# Epoch 10/100
#  - 0s - loss: 257.5793
# Epoch 11/100
#  - 0s - loss: 242.1972
# Epoch 12/100
#  - 0s - loss: 226.3104
# Epoch 13/100
#  - 0s - loss: 204.7829
# Epoch 14/100
#  - 0s - loss: 200.6899
# Epoch 15/100
#  - 0s - loss: 196.1857
# Epoch 16/100
#  - 0s - loss: 190.1792
# Epoch 17/100
#  - 0s - loss: 185.8922
# Epoch 18/100
#  - 0s - loss: 181.8885
# Epoch 19/100
#  - 0s - loss: 179.4528
# Epoch 20/100
#  - 0s - loss: 175.5951
# Epoch 21/100
#  - 0s - loss: 172.7654
# Epoch 22/100
#  - 0s - loss: 170.0737
# Epoch 23/100
#  - 0s - loss: 167.6952
# Epoch 24/100
#  - 0s - loss: 165.2074
# Epoch 25/100
#  - 0s - loss: 162.7911
# Epoch 26/100
#  - 0s - loss: 160.6992
# Epoch 27/100
#  - 0s - loss: 158.3706
# Epoch 28/100
#  - 0s - loss: 156.2755
# Epoch 29/100
#  - 0s - loss: 154.6621
# Epoch 30/100
#  - 0s - loss: 152.5781
# Epoch 31/100
#  - 0s - loss: 151.0039
# Epoch 32/100
#  - 0s - loss: 148.9968
# Epoch 33/100
#  - 0s - loss: 147.2874
# Epoch 34/100
#  - 0s - loss: 145.5701
# Epoch 35/100
#  - 0s - loss: 144.1717
# Epoch 36/100
#  - 0s - loss: 142.0945
# Epoch 37/100
#  - 0s - loss: 140.7493
# Epoch 38/100
#  - 0s - loss: 139.2165
# Epoch 39/100
#  - 0s - loss: 137.2973
# Epoch 40/100
#  - 0s - loss: 135.9870
# Epoch 41/100
#  - 0s - loss: 134.0721
# Epoch 42/100
#  - 0s - loss: 133.1856
# Epoch 43/100
#  - 0s - loss: 132.1430
# Epoch 44/100
#  - 0s - loss: 129.3032
# Epoch 45/100
#  - 0s - loss: 127.7875
# Epoch 46/100
#  - 0s - loss: 126.5157
# Epoch 47/100
#  - 0s - loss: 124.6309
# Epoch 48/100
#  - 0s - loss: 123.1531
# Epoch 49/100
#  - 0s - loss: 121.3030
# Epoch 50/100
#  - 0s - loss: 118.7662
# Epoch 51/100
#  - 0s - loss: 117.6447
# Epoch 52/100
#  - 0s - loss: 115.1439
# Epoch 53/100
#  - 0s - loss: 111.5207
# Epoch 54/100
#  - 0s - loss: 110.5237
# Epoch 55/100
#  - 0s - loss: 107.2911
# Epoch 56/100
#  - 0s - loss: 105.2884
# Epoch 57/100
#  - 0s - loss: 102.4362
# Epoch 58/100
#  - 0s - loss: 100.7364
# Epoch 59/100
#  - 0s - loss: 98.4890
# Epoch 60/100
#  - 0s - loss: 96.0210
# Epoch 61/100
#  - 0s - loss: 93.5523
# Epoch 62/100
#  - 0s - loss: 90.6279
# Epoch 63/100
#  - 0s - loss: 88.5356
# Epoch 64/100
#  - 0s - loss: 86.3828
# Epoch 65/100
#  - 0s - loss: 83.8823
# Epoch 66/100
#  - 0s - loss: 81.6422
# Epoch 67/100
#  - 0s - loss: 79.5686
# Epoch 68/100
#  - 0s - loss: 77.3908
# Epoch 69/100
#  - 0s - loss: 75.6415
# Epoch 70/100
#  - 0s - loss: 73.6056
# Epoch 71/100
#  - 0s - loss: 71.3813
# Epoch 72/100
#  - 0s - loss: 69.7906
# Epoch 73/100
#  - 0s - loss: 67.8505
# Epoch 74/100
#  - 0s - loss: 65.7393
# Epoch 75/100
#  - 0s - loss: 64.1348
# Epoch 76/100
#  - 0s - loss: 63.1438
# Epoch 77/100
#  - 0s - loss: 61.7481
# Epoch 78/100
#  - 0s - loss: 59.6526
# Epoch 79/100
#  - 0s - loss: 58.6979
# Epoch 80/100
#  - 0s - loss: 57.6184
# Epoch 81/100
#  - 0s - loss: 56.0257
# Epoch 82/100
#  - 0s - loss: 54.6129
# Epoch 83/100
#  - 0s - loss: 53.8020
# Epoch 84/100
#  - 0s - loss: 52.5879
# Epoch 85/100
#  - 0s - loss: 51.3317
# Epoch 86/100
#  - 0s - loss: 51.0799
# Epoch 87/100
#  - 0s - loss: 49.9727
# Epoch 88/100
#  - 0s - loss: 49.0223
# Epoch 89/100
#  - 0s - loss: 48.6817
# Epoch 90/100
#  - 0s - loss: 47.1654
# Epoch 91/100
#  - 0s - loss: 46.7527
# Epoch 92/100
#  - 0s - loss: 46.4609
# Epoch 93/100
#  - 0s - loss: 45.4274
# Epoch 94/100
#  - 0s - loss: 44.4671
# Epoch 95/100
#  - 0s - loss: 43.7052
# Epoch 96/100
#  - 0s - loss: 43.1349
# Epoch 97/100
#  - 0s - loss: 42.9238
# Epoch 98/100
#  - 0s - loss: 41.9089
# Epoch 99/100
#  - 0s - loss: 41.8403
# Epoch 100/100
#  - 0s - loss: 41.2364
# Executing op __inference_keras_scratch_graph_4282 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op __inference_keras_scratch_graph_4349 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op RandomUniform in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op RandomUniform in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op RandomUniform in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op RandomUniform in device /job:localhost/replica:0/task:0/device:GPU:0
# Epoch 1/100
# Executing op __inference_keras_scratch_graph_5439 in device /job:localhost/replica:0/task:0/device:GPU:0
#  - 0s - loss: 1545.7622
# Epoch 2/100
#  - 0s - loss: 1487.9435
# Epoch 3/100
#  - 0s - loss: 1405.2906
# Epoch 4/100
#  - 0s - loss: 1284.0523
# Epoch 5/100
#  - 0s - loss: 1110.2502
# Epoch 6/100
#  - 0s - loss: 876.4951
# Epoch 7/100
#  - 0s - loss: 606.1316
# Epoch 8/100
#  - 0s - loss: 386.0484
# Epoch 9/100
#  - 0s - loss: 275.5456
# Epoch 10/100
#  - 0s - loss: 257.6672
# Epoch 11/100
#  - 0s - loss: 237.6946
# Epoch 12/100
#  - 0s - loss: 218.5016
# Epoch 13/100
#  - 0s - loss: 209.7948
# Epoch 14/100
#  - 0s - loss: 202.4274
# Epoch 15/100
#  - 0s - loss: 197.0111
# Epoch 16/100
#  - 0s - loss: 191.1909
# Epoch 17/100
#  - 0s - loss: 187.2634
# Epoch 18/100
#  - 0s - loss: 183.4325
# Epoch 19/100
#  - 0s - loss: 178.9906
# Epoch 20/100
#  - 0s - loss: 175.8168
# Epoch 21/100
#  - 0s - loss: 171.9002
# Epoch 22/100
#  - 0s - loss: 169.1347
# Epoch 23/100
#  - 0s - loss: 165.8497
# Epoch 24/100
#  - 0s - loss: 162.8345
# Epoch 25/100
#  - 0s - loss: 160.9429
# Epoch 26/100
#  - 0s - loss: 157.9962
# Epoch 27/100
#  - 0s - loss: 155.1355
# Epoch 28/100
#  - 0s - loss: 152.7057
# Epoch 29/100
#  - 0s - loss: 150.0874
# Epoch 30/100
#  - 0s - loss: 147.5846
# Epoch 31/100
#  - 0s - loss: 145.3000
# Epoch 32/100
#  - 0s - loss: 142.9579
# Epoch 33/100
#  - 0s - loss: 141.0213
# Epoch 34/100
#  - 0s - loss: 138.5669
# Epoch 35/100
#  - 0s - loss: 136.6586
# Epoch 36/100
#  - 0s - loss: 134.6870
# Epoch 37/100
#  - 0s - loss: 132.7296
# Epoch 38/100
#  - 0s - loss: 130.4990
# Epoch 39/100
#  - 0s - loss: 128.6014
# Epoch 40/100
#  - 0s - loss: 127.2674
# Epoch 41/100
#  - 0s - loss: 124.3022
# Epoch 42/100
#  - 0s - loss: 123.3011
# Epoch 43/100
#  - 0s - loss: 121.0798
# Epoch 44/100
#  - 0s - loss: 119.9183
# Epoch 45/100
#  - 0s - loss: 117.3283
# Epoch 46/100
#  - 0s - loss: 115.6791
# Epoch 47/100
#  - 0s - loss: 113.6049
# Epoch 48/100
#  - 0s - loss: 111.8250
# Epoch 49/100
#  - 0s - loss: 110.3920
# Epoch 50/100
#  - 0s - loss: 108.8192
# Epoch 51/100
#  - 0s - loss: 106.9489
# Epoch 52/100
#  - 0s - loss: 105.1882
# Epoch 53/100
#  - 0s - loss: 103.2945
# Epoch 54/100
#  - 0s - loss: 102.4301
# Epoch 55/100
#  - 0s - loss: 100.4999
# Epoch 56/100
#  - 0s - loss: 98.4218
# Epoch 57/100
#  - 0s - loss: 96.8310
# Epoch 58/100
#  - 0s - loss: 95.0948
# Epoch 59/100
#  - 0s - loss: 93.7754
# Epoch 60/100
#  - 0s - loss: 92.3401
# Epoch 61/100
#  - 0s - loss: 90.8215
# Epoch 62/100
#  - 0s - loss: 89.6731
# Epoch 63/100
#  - 0s - loss: 87.6499
# Epoch 64/100
#  - 0s - loss: 86.1382
# Epoch 65/100
#  - 0s - loss: 84.7449
# Epoch 66/100
#  - 0s - loss: 83.6375
# Epoch 67/100
#  - 0s - loss: 81.8107
# Epoch 68/100
#  - 0s - loss: 80.6851
# Epoch 69/100
#  - 0s - loss: 79.1461
# Epoch 70/100
#  - 0s - loss: 78.0356
# Epoch 71/100
#  - 0s - loss: 76.4745
# Epoch 72/100
#  - 0s - loss: 75.1654
# Epoch 73/100
#  - 0s - loss: 74.3452
# Epoch 74/100
#  - 0s - loss: 73.3084
# Epoch 75/100
#  - 0s - loss: 72.3754
# Epoch 76/100
#  - 0s - loss: 70.8095
# Epoch 77/100
#  - 0s - loss: 69.9638
# Epoch 78/100
#  - 0s - loss: 68.5197
# Epoch 79/100
#  - 0s - loss: 67.1763
# Epoch 80/100
#  - 0s - loss: 66.4088
# Epoch 81/100
#  - 0s - loss: 64.9924
# Epoch 82/100
#  - 0s - loss: 63.9762
# Epoch 83/100
#  - 0s - loss: 62.6519
# Epoch 84/100
#  - 0s - loss: 61.8727
# Epoch 85/100
#  - 0s - loss: 60.6109
# Epoch 86/100
#  - 0s - loss: 59.4221
# Epoch 87/100
#  - 0s - loss: 58.3795
# Epoch 88/100
#  - 0s - loss: 57.2167
# Epoch 89/100
#  - 0s - loss: 56.2086
# Epoch 90/100
#  - 0s - loss: 55.2713
# Epoch 91/100
#  - 0s - loss: 54.2684
# Epoch 92/100
#  - 0s - loss: 53.3781
# Epoch 93/100
#  - 0s - loss: 53.4440
# Epoch 94/100
#  - 0s - loss: 51.6790
# Epoch 95/100
#  - 0s - loss: 51.0891
# Epoch 96/100
#  - 0s - loss: 50.3317
# Epoch 97/100
#  - 0s - loss: 50.0171
# Epoch 98/100
#  - 0s - loss: 48.5374
# Epoch 99/100
#  - 0s - loss: 47.4368
# Epoch 100/100
#  - 0s - loss: 46.6413
# Executing op __inference_keras_scratch_graph_8670 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op __inference_keras_scratch_graph_8737 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op RandomUniform in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op RandomUniform in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op RandomUniform in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op RandomUniform in device /job:localhost/replica:0/task:0/device:GPU:0
# Epoch 1/100
# Executing op __inference_keras_scratch_graph_9827 in device /job:localhost/replica:0/task:0/device:GPU:0
#  - 0s - loss: 1574.4037
# Epoch 2/100
#  - 0s - loss: 1530.9004
# Epoch 3/100
#  - 0s - loss: 1474.4094
# Epoch 4/100
#  - 0s - loss: 1390.8212
# Epoch 5/100
#  - 0s - loss: 1272.9620
# Epoch 6/100
#  - 0s - loss: 1100.9986
# Epoch 7/100
#  - 0s - loss: 875.8318
# Epoch 8/100
#  - 0s - loss: 618.7869
# Epoch 9/100
#  - 0s - loss: 400.5204
# Epoch 10/100
#  - 0s - loss: 297.7784
# Epoch 11/100
#  - 0s - loss: 274.3924
# Epoch 12/100
#  - 0s - loss: 251.8610
# Epoch 13/100
#  - 0s - loss: 229.7565
# Epoch 14/100
#  - 0s - loss: 219.3209
# Epoch 15/100
#  - 0s - loss: 211.1270
# Epoch 16/100
#  - 0s - loss: 203.9370
# Epoch 17/100
#  - 0s - loss: 198.3982
# Epoch 18/100
#  - 0s - loss: 192.9183
# Epoch 19/100
#  - 0s - loss: 188.1555
# Epoch 20/100
#  - 0s - loss: 183.8791
# Epoch 21/100
#  - 0s - loss: 179.8436
# Epoch 22/100
#  - 0s - loss: 176.6039
# Epoch 23/100
#  - 0s - loss: 173.2818
# Epoch 24/100
#  - 0s - loss: 169.7487
# Epoch 25/100
#  - 0s - loss: 167.6497
# Epoch 26/100
#  - 0s - loss: 164.5100
# Epoch 27/100
#  - 0s - loss: 161.1915
# Epoch 28/100
#  - 0s - loss: 159.3090
# Epoch 29/100
#  - 0s - loss: 156.8237
# Epoch 30/100
#  - 0s - loss: 155.1748
# Epoch 31/100
#  - 0s - loss: 152.1837
# Epoch 32/100
#  - 0s - loss: 150.5412
# Epoch 33/100
#  - 0s - loss: 148.7847
# Epoch 34/100
#  - 0s - loss: 146.6247
# Epoch 35/100
#  - 0s - loss: 144.8452
# Epoch 36/100
#  - 0s - loss: 142.7046
# Epoch 37/100
#  - 0s - loss: 141.7510
# Epoch 38/100
#  - 0s - loss: 139.2806
# Epoch 39/100
#  - 0s - loss: 137.3906
# Epoch 40/100
#  - 0s - loss: 135.4866
# Epoch 41/100
#  - 0s - loss: 134.5052
# Epoch 42/100
#  - 0s - loss: 132.2637
# Epoch 43/100
#  - 0s - loss: 130.5256
# Epoch 44/100
#  - 0s - loss: 128.5927
# Epoch 45/100
#  - 0s - loss: 127.0039
# Epoch 46/100
#  - 0s - loss: 125.6483
# Epoch 47/100
#  - 0s - loss: 124.2541
# Epoch 48/100
#  - 0s - loss: 121.9922
# Epoch 49/100
#  - 0s - loss: 120.2689
# Epoch 50/100
#  - 0s - loss: 118.8298
# Epoch 51/100
#  - 0s - loss: 117.1944
# Epoch 52/100
#  - 0s - loss: 115.8124
# Epoch 53/100
#  - 0s - loss: 113.9375
# Epoch 54/100
#  - 0s - loss: 112.8655
# Epoch 55/100
#  - 0s - loss: 110.5002
# Epoch 56/100
#  - 0s - loss: 109.3709
# Epoch 57/100
#  - 0s - loss: 108.0499
# Epoch 58/100
#  - 0s - loss: 105.9726
# Epoch 59/100
#  - 0s - loss: 103.8233
# Epoch 60/100
#  - 0s - loss: 102.5742
# Epoch 61/100
#  - 0s - loss: 100.4542
# Epoch 62/100
#  - 0s - loss: 98.9843
# Epoch 63/100
#  - 0s - loss: 97.0883
# Epoch 64/100
#  - 0s - loss: 95.4396
# Epoch 65/100
#  - 0s - loss: 94.6284
# Epoch 66/100
#  - 0s - loss: 92.3817
# Epoch 67/100
#  - 0s - loss: 90.6496
# Epoch 68/100
#  - 0s - loss: 89.2443
# Epoch 69/100
#  - 0s - loss: 87.4221
# Epoch 70/100
#  - 0s - loss: 86.5082
# Epoch 71/100
#  - 0s - loss: 83.8283
# Epoch 72/100
#  - 0s - loss: 82.6142
# Epoch 73/100
#  - 0s - loss: 81.0378
# Epoch 74/100
#  - 0s - loss: 80.5390
# Epoch 75/100
#  - 0s - loss: 79.4130
# Epoch 76/100
#  - 0s - loss: 78.2775
# Epoch 77/100
#  - 0s - loss: 75.9145
# Epoch 78/100
#  - 0s - loss: 74.5190
# Epoch 79/100
#  - 0s - loss: 73.0638
# Epoch 80/100
#  - 0s - loss: 72.2975
# Epoch 81/100
#  - 0s - loss: 70.6969
# Epoch 82/100
#  - 0s - loss: 69.7371
# Epoch 83/100
#  - 0s - loss: 68.1650
# Epoch 84/100
#  - 0s - loss: 67.0147
# Epoch 85/100
#  - 0s - loss: 66.1938
# Epoch 86/100
#  - 0s - loss: 64.4131
# Epoch 87/100
#  - 0s - loss: 63.2303
# Epoch 88/100
#  - 0s - loss: 61.9136
# Epoch 89/100
#  - 0s - loss: 60.8235
# Epoch 90/100
#  - 0s - loss: 59.4931
# Epoch 91/100
#  - 0s - loss: 58.7682
# Epoch 92/100
#  - 0s - loss: 57.5937
# Epoch 93/100
#  - 0s - loss: 56.6590
# Epoch 94/100
#  - 0s - loss: 55.4536
# Epoch 95/100
#  - 0s - loss: 55.1089
# Epoch 96/100
#  - 0s - loss: 54.2825
# Epoch 97/100
#  - 0s - loss: 53.2635
# Epoch 98/100
#  - 0s - loss: 52.6004
# Epoch 99/100
#  - 0s - loss: 52.0381
# Epoch 100/100
#  - 0s - loss: 50.9551
# Executing op __inference_keras_scratch_graph_13058 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op __inference_keras_scratch_graph_13125 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op RandomUniform in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op RandomUniform in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op RandomUniform in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op RandomUniform in device /job:localhost/replica:0/task:0/device:GPU:0
# Epoch 1/100
# Executing op __inference_keras_scratch_graph_14215 in device /job:localhost/replica:0/task:0/device:GPU:0
#  - 0s - loss: 1572.2484
# Epoch 2/100
#  - 0s - loss: 1536.4697
# Epoch 3/100
#  - 0s - loss: 1483.6958
# Epoch 4/100
#  - 0s - loss: 1403.5088
# Epoch 5/100
#  - 0s - loss: 1278.1345
# Epoch 6/100
#  - 0s - loss: 1093.5268
# Epoch 7/100
#  - 0s - loss: 850.8805
# Epoch 8/100
#  - 0s - loss: 569.7395
# Epoch 9/100
#  - 0s - loss: 346.1290
# Epoch 10/100
#  - 0s - loss: 269.2515
# Epoch 11/100
#  - 0s - loss: 256.0659
# Epoch 12/100
#  - 0s - loss: 230.7561
# Epoch 13/100
#  - 0s - loss: 215.8334
# Epoch 14/100
#  - 0s - loss: 209.5979
# Epoch 15/100
#  - 0s - loss: 202.2647
# Epoch 16/100
#  - 0s - loss: 195.6075
# Epoch 17/100
#  - 0s - loss: 190.9405
# Epoch 18/100
#  - 0s - loss: 186.5800
# Epoch 19/100
#  - 0s - loss: 182.3292
# Epoch 20/100
#  - 0s - loss: 178.2912
# Epoch 21/100
#  - 0s - loss: 174.6984
# Epoch 22/100
#  - 0s - loss: 171.8044
# Epoch 23/100
#  - 0s - loss: 168.5542
# Epoch 24/100
#  - 0s - loss: 165.9790
# Epoch 25/100
#  - 0s - loss: 163.6778
# Epoch 26/100
#  - 0s - loss: 161.1255
# Epoch 27/100
#  - 0s - loss: 159.2666
# Epoch 28/100
#  - 0s - loss: 157.4903
# Epoch 29/100
#  - 0s - loss: 154.0588
# Epoch 30/100
#  - 0s - loss: 152.0301
# Epoch 31/100
#  - 0s - loss: 149.9551
# Epoch 32/100
#  - 0s - loss: 147.5315
# Epoch 33/100
#  - 0s - loss: 145.7149
# Epoch 34/100
#  - 0s - loss: 144.1178
# Epoch 35/100
#  - 0s - loss: 141.7655
# Epoch 36/100
#  - 0s - loss: 139.7901
# Epoch 37/100
#  - 0s - loss: 138.2306
# Epoch 38/100
#  - 0s - loss: 135.6619
# Epoch 39/100
#  - 0s - loss: 134.0104
# Epoch 40/100
#  - 0s - loss: 131.9313
# Epoch 41/100
#  - 0s - loss: 130.4193
# Epoch 42/100
#  - 0s - loss: 128.5588
# Epoch 43/100
#  - 0s - loss: 126.3592
# Epoch 44/100
#  - 0s - loss: 124.1812
# Epoch 45/100
#  - 0s - loss: 122.1576
# Epoch 46/100
#  - 0s - loss: 120.2768
# Epoch 47/100
#  - 0s - loss: 117.9951
# Epoch 48/100
#  - 0s - loss: 115.9168
# Epoch 49/100
#  - 0s - loss: 113.3692
# Epoch 50/100
#  - 0s - loss: 110.8501
# Epoch 51/100
#  - 0s - loss: 108.5224
# Epoch 52/100
#  - 0s - loss: 105.8790
# Epoch 53/100
#  - 0s - loss: 103.2994
# Epoch 54/100
#  - 0s - loss: 101.1702
# Epoch 55/100
#  - 0s - loss: 98.7990
# Epoch 56/100
#  - 0s - loss: 96.1324
# Epoch 57/100
#  - 0s - loss: 93.4555
# Epoch 58/100
#  - 0s - loss: 91.7415
# Epoch 59/100
#  - 0s - loss: 89.1413
# Epoch 60/100
#  - 0s - loss: 86.2373
# Epoch 61/100
#  - 0s - loss: 83.6299
# Epoch 62/100
#  - 0s - loss: 81.3883
# Epoch 63/100
#  - 0s - loss: 79.5306
# Epoch 64/100
#  - 0s - loss: 77.0288
# Epoch 65/100
#  - 0s - loss: 74.5755
# Epoch 66/100
#  - 0s - loss: 72.2635
# Epoch 67/100
#  - 0s - loss: 71.1109
# Epoch 68/100
#  - 0s - loss: 68.9086
# Epoch 69/100
#  - 0s - loss: 67.2334
# Epoch 70/100
#  - 0s - loss: 65.4488
# Epoch 71/100
#  - 0s - loss: 64.5736
# Epoch 72/100
#  - 0s - loss: 62.4445
# Epoch 73/100
#  - 0s - loss: 61.3748
# Epoch 74/100
#  - 0s - loss: 59.4797
# Epoch 75/100
#  - 0s - loss: 57.8527
# Epoch 76/100
#  - 0s - loss: 56.4430
# Epoch 77/100
#  - 0s - loss: 55.1345
# Epoch 78/100
#  - 0s - loss: 54.0423
# Epoch 79/100
#  - 0s - loss: 52.8040
# Epoch 80/100
#  - 0s - loss: 51.7777
# Epoch 81/100
#  - 0s - loss: 50.6901
# Epoch 82/100
#  - 0s - loss: 49.9756
# Epoch 83/100
#  - 0s - loss: 48.8840
# Epoch 84/100
#  - 0s - loss: 48.6939
# Epoch 85/100
#  - 0s - loss: 47.2731
# Epoch 86/100
#  - 0s - loss: 46.2014
# Epoch 87/100
#  - 0s - loss: 45.8191
# Epoch 88/100
#  - 0s - loss: 44.4554
# Epoch 89/100
#  - 0s - loss: 44.1564
# Epoch 90/100
#  - 0s - loss: 43.6410
# Epoch 91/100
#  - 0s - loss: 42.6920
# Epoch 92/100
#  - 0s - loss: 41.8869
# Epoch 93/100
#  - 0s - loss: 41.3731
# Epoch 94/100
#  - 0s - loss: 40.6816
# Epoch 95/100
#  - 0s - loss: 40.0590
# Epoch 96/100
#  - 0s - loss: 39.5491
# Epoch 97/100
#  - 0s - loss: 39.2080
# Epoch 98/100
#  - 0s - loss: 38.7461
# Epoch 99/100
#  - 0s - loss: 38.0526
# Epoch 100/100
#  - 0s - loss: 37.2292
# Executing op __inference_keras_scratch_graph_17446 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op __inference_keras_scratch_graph_17513 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op RandomUniform in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op RandomUniform in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op RandomUniform in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op RandomUniform in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op DestroyResourceOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Epoch 1/100
# Executing op __inference_keras_scratch_graph_18603 in device /job:localhost/replica:0/task:0/device:GPU:0
#  - 0s - loss: 1567.2508
# Epoch 2/100
#  - 0s - loss: 1515.9205
# Epoch 3/100
#  - 0s - loss: 1448.7933
# Epoch 4/100
#  - 0s - loss: 1354.3753
# Epoch 5/100
#  - 0s - loss: 1212.7903
# Epoch 6/100
#  - 0s - loss: 1018.8091
# Epoch 7/100
#  - 0s - loss: 764.1280
# Epoch 8/100
#  - 0s - loss: 498.2431
# Epoch 9/100
#  - 0s - loss: 309.6076
# Epoch 10/100
#  - 0s - loss: 262.6897
# Epoch 11/100
#  - 0s - loss: 251.3698
# Epoch 12/100
#  - 0s - loss: 229.1825
# Epoch 13/100
#  - 0s - loss: 217.6595
# Epoch 14/100
#  - 0s - loss: 210.2590
# Epoch 15/100
#  - 0s - loss: 202.9276
# Epoch 16/100
#  - 0s - loss: 196.9511
# Epoch 17/100
#  - 0s - loss: 192.6330
# Epoch 18/100
#  - 0s - loss: 186.7232
# Epoch 19/100
#  - 0s - loss: 181.9553
# Epoch 20/100
#  - 0s - loss: 178.5129
# Epoch 21/100
#  - 0s - loss: 174.8098
# Epoch 22/100
#  - 0s - loss: 171.5420
# Epoch 23/100
#  - 0s - loss: 168.6650
# Epoch 24/100
#  - 0s - loss: 165.9365
# Epoch 25/100
#  - 0s - loss: 162.8621
# Epoch 26/100
#  - 0s - loss: 160.4962
# Epoch 27/100
#  - 0s - loss: 157.9461
# Epoch 28/100
#  - 0s - loss: 156.1769
# Epoch 29/100
#  - 0s - loss: 154.2901
# Epoch 30/100
#  - 0s - loss: 151.8748
# Epoch 31/100
#  - 0s - loss: 150.1469
# Epoch 32/100
#  - 0s - loss: 148.3851
# Epoch 33/100
#  - 0s - loss: 146.3543
# Epoch 34/100
#  - 0s - loss: 144.9669
# Epoch 35/100
#  - 0s - loss: 142.8335
# Epoch 36/100
#  - 0s - loss: 141.5740
# Epoch 37/100
#  - 0s - loss: 139.5073
# Epoch 38/100
#  - 0s - loss: 137.8122
# Epoch 39/100
#  - 0s - loss: 136.9296
# Epoch 40/100
#  - 0s - loss: 134.4657
# Epoch 41/100
#  - 0s - loss: 134.8010
# Epoch 42/100
#  - 0s - loss: 131.7628
# Epoch 43/100
#  - 0s - loss: 130.3644
# Epoch 44/100
#  - 0s - loss: 128.5031
# Epoch 45/100
#  - 0s - loss: 126.9992
# Epoch 46/100
#  - 0s - loss: 125.2202
# Epoch 47/100
#  - 0s - loss: 123.8530
# Epoch 48/100
#  - 0s - loss: 121.6643
# Epoch 49/100
#  - 0s - loss: 119.6306
# Epoch 50/100
#  - 0s - loss: 117.8727
# Epoch 51/100
#  - 0s - loss: 115.5796
# Epoch 52/100
#  - 0s - loss: 113.8822
# Epoch 53/100
#  - 0s - loss: 111.5687
# Epoch 54/100
#  - 0s - loss: 109.6222
# Epoch 55/100
#  - 0s - loss: 106.4425
# Epoch 56/100
#  - 0s - loss: 104.4119
# Epoch 57/100
#  - 0s - loss: 102.7855
# Epoch 58/100
#  - 0s - loss: 99.4736
# Epoch 59/100
#  - 0s - loss: 96.7606
# Epoch 60/100
#  - 0s - loss: 94.3699
# Epoch 61/100
#  - 0s - loss: 91.7073
# Epoch 62/100
#  - 0s - loss: 88.9677
# Epoch 63/100
#  - 0s - loss: 86.4675
# Epoch 64/100
#  - 0s - loss: 83.7977
# Epoch 65/100
#  - 0s - loss: 81.6744
# Epoch 66/100
#  - 0s - loss: 80.1369
# Epoch 67/100
#  - 0s - loss: 77.0451
# Epoch 68/100
#  - 0s - loss: 74.7784
# Epoch 69/100
#  - 0s - loss: 72.7120
# Epoch 70/100
#  - 0s - loss: 70.6039
# Epoch 71/100
#  - 0s - loss: 68.6157
# Epoch 72/100
#  - 0s - loss: 67.5833
# Epoch 73/100
#  - 0s - loss: 65.2429
# Epoch 74/100
#  - 0s - loss: 63.8227
# Epoch 75/100
#  - 0s - loss: 62.0341
# Epoch 76/100
#  - 0s - loss: 60.5819
# Epoch 77/100
#  - 0s - loss: 59.2117
# Epoch 78/100
#  - 0s - loss: 58.2801
# Epoch 79/100
#  - 0s - loss: 56.9678
# Epoch 80/100
#  - 0s - loss: 55.7762
# Epoch 81/100
#  - 0s - loss: 54.8793
# Epoch 82/100
#  - 0s - loss: 54.2399
# Epoch 83/100
#  - 0s - loss: 53.4021
# Epoch 84/100
#  - 0s - loss: 51.8182
# Epoch 85/100
#  - 0s - loss: 51.0819
# Epoch 86/100
#  - 0s - loss: 50.2713
# Epoch 87/100
#  - 0s - loss: 49.5248
# Epoch 88/100
#  - 0s - loss: 48.3679
# Epoch 89/100
#  - 0s - loss: 48.0504
# Epoch 90/100
#  - 0s - loss: 47.0890
# Epoch 91/100
#  - 0s - loss: 46.5513
# Epoch 92/100
#  - 0s - loss: 45.5058
# Epoch 93/100
#  - 0s - loss: 44.9826
# Epoch 94/100
#  - 0s - loss: 44.4659
# Epoch 95/100
#  - 0s - loss: 44.0529
# Epoch 96/100
#  - 0s - loss: 43.3777
# Epoch 97/100
#  - 0s - loss: 42.6054
# Epoch 98/100
#  - 0s - loss: 42.4636
# Epoch 99/100
#  - 0s - loss: 42.4729
# Epoch 100/100
#  - 0s - loss: 41.3110
# Executing op __inference_keras_scratch_graph_21834 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op __inference_keras_scratch_graph_21901 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op RandomUniform in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op RandomUniform in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op RandomUniform in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op RandomUniform in device /job:localhost/replica:0/task:0/device:GPU:0
# Epoch 1/100
# Executing op __inference_keras_scratch_graph_22991 in device /job:localhost/replica:0/task:0/device:GPU:0
#  - 0s - loss: 1587.3765
# Epoch 2/100
#  - 0s - loss: 1549.9522
# Epoch 3/100
#  - 0s - loss: 1502.1202
# Epoch 4/100
#  - 0s - loss: 1432.9799
# Epoch 5/100
#  - 0s - loss: 1328.5402
# Epoch 6/100
#  - 0s - loss: 1175.4607
# Epoch 7/100
#  - 0s - loss: 968.5580
# Epoch 8/100
#  - 0s - loss: 721.9196
# Epoch 9/100
#  - 0s - loss: 489.2919
# Epoch 10/100
#  - 0s - loss: 344.4031
# Epoch 11/100
#  - 0s - loss: 298.8739
# Epoch 12/100
#  - 0s - loss: 269.4921
# Epoch 13/100
#  - 0s - loss: 242.1915
# Epoch 14/100
#  - 0s - loss: 229.3275
# Epoch 15/100
#  - 0s - loss: 220.7111
# Epoch 16/100
#  - 0s - loss: 213.1888
# Epoch 17/100
#  - 0s - loss: 206.6403
# Epoch 18/100
#  - 0s - loss: 201.4756
# Epoch 19/100
#  - 0s - loss: 197.1062
# Epoch 20/100
#  - 0s - loss: 192.7436
# Epoch 21/100
#  - 0s - loss: 188.2136
# Epoch 22/100
#  - 0s - loss: 184.7965
# Epoch 23/100
#  - 0s - loss: 180.6435
# Epoch 24/100
#  - 0s - loss: 176.6196
# Epoch 25/100
#  - 0s - loss: 173.1767
# Epoch 26/100
#  - 0s - loss: 170.0246
# Epoch 27/100
#  - 0s - loss: 166.7079
# Epoch 28/100
#  - 0s - loss: 164.2575
# Epoch 29/100
#  - 0s - loss: 161.1884
# Epoch 30/100
#  - 0s - loss: 158.4560
# Epoch 31/100
#  - 0s - loss: 155.8313
# Epoch 32/100
#  - 0s - loss: 153.1843
# Epoch 33/100
#  - 0s - loss: 151.5815
# Epoch 34/100
#  - 0s - loss: 148.5797
# Epoch 35/100
#  - 0s - loss: 146.3403
# Epoch 36/100
#  - 0s - loss: 144.1031
# Epoch 37/100
#  - 0s - loss: 141.8044
# Epoch 38/100
#  - 0s - loss: 139.6587
# Epoch 39/100
#  - 0s - loss: 138.0636
# Epoch 40/100
#  - 0s - loss: 135.1066
# Epoch 41/100
#  - 0s - loss: 132.9126
# Epoch 42/100
#  - 0s - loss: 131.2189
# Epoch 43/100
#  - 0s - loss: 128.5272
# Epoch 44/100
#  - 0s - loss: 126.3027
# Epoch 45/100
#  - 0s - loss: 123.8813
# Epoch 46/100
#  - 0s - loss: 121.5837
# Epoch 47/100
#  - 0s - loss: 119.4493
# Epoch 48/100
#  - 0s - loss: 116.9550
# Epoch 49/100
#  - 0s - loss: 114.5498
# Epoch 50/100
#  - 0s - loss: 112.7036
# Epoch 51/100
#  - 0s - loss: 109.9799
# Epoch 52/100
#  - 0s - loss: 107.2848
# Epoch 53/100
#  - 0s - loss: 105.0608
# Epoch 54/100
#  - 0s - loss: 102.2800
# Epoch 55/100
#  - 0s - loss: 99.7062
# Epoch 56/100
#  - 0s - loss: 97.3058
# Epoch 57/100
#  - 0s - loss: 95.2562
# Epoch 58/100
#  - 0s - loss: 92.2870
# Epoch 59/100
#  - 0s - loss: 90.5043
# Epoch 60/100
#  - 0s - loss: 87.4770
# Epoch 61/100
#  - 0s - loss: 85.6584
# Epoch 62/100
#  - 0s - loss: 83.4029
# Epoch 63/100
#  - 0s - loss: 81.4185
# Epoch 64/100
#  - 0s - loss: 79.1353
# Epoch 65/100
#  - 0s - loss: 77.4390
# Epoch 66/100
#  - 0s - loss: 76.0322
# Epoch 67/100
#  - 0s - loss: 73.6550
# Epoch 68/100
#  - 0s - loss: 72.4173
# Epoch 69/100
#  - 0s - loss: 70.6252
# Epoch 70/100
#  - 0s - loss: 69.8292
# Epoch 71/100
#  - 0s - loss: 67.8195
# Epoch 72/100
#  - 0s - loss: 66.4027
# Epoch 73/100
#  - 0s - loss: 64.9066
# Epoch 74/100
#  - 0s - loss: 64.1459
# Epoch 75/100
#  - 0s - loss: 62.4154
# Epoch 76/100
#  - 0s - loss: 61.5742
# Epoch 77/100
#  - 0s - loss: 60.1916
# Epoch 78/100
#  - 0s - loss: 59.3569
# Epoch 79/100
#  - 0s - loss: 58.0631
# Epoch 80/100
#  - 0s - loss: 56.9062
# Epoch 81/100
#  - 0s - loss: 55.6425
# Epoch 82/100
#  - 0s - loss: 55.2589
# Epoch 83/100
#  - 0s - loss: 53.6891
# Epoch 84/100
#  - 0s - loss: 52.8729
# Epoch 85/100
#  - 0s - loss: 51.7807
# Epoch 86/100
#  - 0s - loss: 50.9387
# Epoch 87/100
#  - 0s - loss: 49.7789
# Epoch 88/100
#  - 0s - loss: 48.3377
# Epoch 89/100
#  - 0s - loss: 47.3562
# Epoch 90/100
#  - 0s - loss: 46.4780
# Epoch 91/100
#  - 0s - loss: 45.5364
# Epoch 92/100
#  - 0s - loss: 44.6116
# Epoch 93/100
#  - 0s - loss: 43.7068
# Epoch 94/100
#  - 0s - loss: 42.8394
# Epoch 95/100
#  - 0s - loss: 42.2412
# Epoch 96/100
#  - 0s - loss: 41.3028
# Epoch 97/100
#  - 0s - loss: 40.9019
# Epoch 98/100
#  - 0s - loss: 40.1872
# Epoch 99/100
#  - 0s - loss: 39.3784
# Epoch 100/100
#  - 0s - loss: 39.1228
# Executing op __inference_keras_scratch_graph_26222 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op __inference_keras_scratch_graph_26289 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op RandomUniform in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op RandomUniform in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op RandomUniform in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op RandomUniform in device /job:localhost/replica:0/task:0/device:GPU:0
# Epoch 1/100
# Executing op __inference_keras_scratch_graph_27379 in device /job:localhost/replica:0/task:0/device:GPU:0
#  - 0s - loss: 1540.6099
# Epoch 2/100
#  - 0s - loss: 1484.2057
# Epoch 3/100
#  - 0s - loss: 1402.8393
# Epoch 4/100
#  - 0s - loss: 1282.8107
# Epoch 5/100
#  - 0s - loss: 1113.4525
# Epoch 6/100
#  - 0s - loss: 885.2100
# Epoch 7/100
#  - 0s - loss: 621.9663
# Epoch 8/100
#  - 0s - loss: 390.6699
# Epoch 9/100
#  - 0s - loss: 275.9410
# Epoch 10/100
#  - 0s - loss: 267.2529
# Epoch 11/100
#  - 0s - loss: 244.8177
# Epoch 12/100
#  - 0s - loss: 226.3887
# Epoch 13/100
#  - 0s - loss: 218.0937
# Epoch 14/100
#  - 0s - loss: 210.3292
# Epoch 15/100
#  - 0s - loss: 203.7539
# Epoch 16/100
#  - 0s - loss: 197.6461
# Epoch 17/100
#  - 0s - loss: 192.5278
# Epoch 18/100
#  - 0s - loss: 187.3534
# Epoch 19/100
#  - 0s - loss: 183.0145
# Epoch 20/100
#  - 0s - loss: 178.8203
# Epoch 21/100
#  - 0s - loss: 175.2985
# Epoch 22/100
#  - 0s - loss: 171.8856
# Epoch 23/100
#  - 0s - loss: 168.1920
# Epoch 24/100
#  - 0s - loss: 165.2052
# Epoch 25/100
#  - 0s - loss: 162.5152
# Epoch 26/100
#  - 0s - loss: 160.1861
# Epoch 27/100
#  - 0s - loss: 156.9506
# Epoch 28/100
#  - 0s - loss: 154.6484
# Epoch 29/100
#  - 0s - loss: 151.9979
# Epoch 30/100
#  - 0s - loss: 150.1503
# Epoch 31/100
#  - 0s - loss: 147.6427
# Epoch 32/100
#  - 0s - loss: 145.6318
# Epoch 33/100
#  - 0s - loss: 143.9703
# Epoch 34/100
#  - 0s - loss: 141.6961
# Epoch 35/100
#  - 0s - loss: 140.0865
# Epoch 36/100
#  - 0s - loss: 138.8774
# Epoch 37/100
#  - 0s - loss: 136.8484
# Epoch 38/100
#  - 0s - loss: 134.9066
# Epoch 39/100
#  - 0s - loss: 133.8112
# Epoch 40/100
#  - 0s - loss: 131.5724
# Epoch 41/100
#  - 0s - loss: 129.9841
# Epoch 42/100
#  - 0s - loss: 128.3438
# Epoch 43/100
#  - 0s - loss: 126.3522
# Epoch 44/100
#  - 0s - loss: 125.4614
# Epoch 45/100
#  - 0s - loss: 123.8710
# Epoch 46/100
#  - 0s - loss: 122.8124
# Epoch 47/100
#  - 0s - loss: 120.7167
# Epoch 48/100
#  - 0s - loss: 118.6422
# Epoch 49/100
#  - 0s - loss: 117.0653
# Epoch 50/100
#  - 0s - loss: 115.9679
# Epoch 51/100
#  - 0s - loss: 114.3221
# Epoch 52/100
#  - 0s - loss: 112.3647
# Epoch 53/100
#  - 0s - loss: 110.5268
# Epoch 54/100
#  - 0s - loss: 108.5504
# Epoch 55/100
#  - 0s - loss: 107.1661
# Epoch 56/100
#  - 0s - loss: 105.4316
# Epoch 57/100
#  - 0s - loss: 103.1857
# Epoch 58/100
#  - 0s - loss: 101.4429
# Epoch 59/100
#  - 0s - loss: 99.1790
# Epoch 60/100
#  - 0s - loss: 96.8073
# Epoch 61/100
#  - 0s - loss: 94.7644
# Epoch 62/100
#  - 0s - loss: 92.9999
# Epoch 63/100
#  - 0s - loss: 90.3972
# Epoch 64/100
#  - 0s - loss: 88.3668
# Epoch 65/100
#  - 0s - loss: 86.5946
# Epoch 66/100
#  - 0s - loss: 84.4318
# Epoch 67/100
#  - 0s - loss: 82.1404
# Epoch 68/100
#  - 0s - loss: 80.0499
# Epoch 69/100
#  - 0s - loss: 78.3542
# Epoch 70/100
#  - 0s - loss: 76.5266
# Epoch 71/100
#  - 0s - loss: 74.9987
# Epoch 72/100
#  - 0s - loss: 73.4954
# Epoch 73/100
#  - 0s - loss: 71.9759
# Epoch 74/100
#  - 0s - loss: 70.5040
# Epoch 75/100
#  - 0s - loss: 68.0694
# Epoch 76/100
#  - 0s - loss: 66.6875
# Epoch 77/100
#  - 0s - loss: 65.0699
# Epoch 78/100
#  - 0s - loss: 63.9077
# Epoch 79/100
#  - 0s - loss: 62.4418
# Epoch 80/100
#  - 0s - loss: 60.6333
# Epoch 81/100
#  - 0s - loss: 60.0413
# Epoch 82/100
#  - 0s - loss: 58.3231
# Epoch 83/100
#  - 0s - loss: 57.0044
# Epoch 84/100
#  - 0s - loss: 56.4854
# Epoch 85/100
#  - 0s - loss: 54.4002
# Epoch 86/100
#  - 0s - loss: 53.5418
# Epoch 87/100
#  - 0s - loss: 52.4515
# Epoch 88/100
#  - 0s - loss: 52.2200
# Epoch 89/100
#  - 0s - loss: 50.8495
# Epoch 90/100
#  - 0s - loss: 49.8728
# Epoch 91/100
#  - 0s - loss: 48.5719
# Epoch 92/100
#  - 0s - loss: 48.0393
# Epoch 93/100
#  - 0s - loss: 46.9580
# Epoch 94/100
#  - 0s - loss: 45.9759
# Epoch 95/100
#  - 0s - loss: 45.3504
# Epoch 96/100
#  - 0s - loss: 44.5692
# Epoch 97/100
#  - 0s - loss: 44.0664
# Epoch 98/100
#  - 0s - loss: 43.5502
# Epoch 99/100
#  - 0s - loss: 42.8677
# Epoch 100/100
#  - 0s - loss: 41.9638
# Executing op __inference_keras_scratch_graph_30610 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op __inference_keras_scratch_graph_30677 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op RandomUniform in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op RandomUniform in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op RandomUniform in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op RandomUniform in device /job:localhost/replica:0/task:0/device:GPU:0
# Epoch 1/100
# Executing op __inference_keras_scratch_graph_31767 in device /job:localhost/replica:0/task:0/device:GPU:0
#  - 0s - loss: 1580.0368
# Epoch 2/100
#  - 0s - loss: 1544.7791
# Epoch 3/100
#  - 0s - loss: 1497.7876
# Epoch 4/100
#  - 0s - loss: 1425.6201
# Epoch 5/100
#  - 0s - loss: 1311.7274
# Epoch 6/100
#  - 0s - loss: 1144.5043
# Epoch 7/100
#  - 0s - loss: 912.8982
# Epoch 8/100
#  - 0s - loss: 638.8055
# Epoch 9/100
#  - 0s - loss: 390.8303
# Epoch 10/100
#  - 0s - loss: 263.0451
# Epoch 11/100
#  - 0s - loss: 258.9645
# Epoch 12/100
#  - 0s - loss: 239.4012
# Epoch 13/100
#  - 0s - loss: 216.1908
# Epoch 14/100
#  - 0s - loss: 208.1031
# Epoch 15/100
#  - 0s - loss: 200.8801
# Epoch 16/100
#  - 0s - loss: 193.5031
# Epoch 17/100
#  - 0s - loss: 188.3647
# Epoch 18/100
#  - 0s - loss: 183.5081
# Epoch 19/100
#  - 0s - loss: 179.6355
# Epoch 20/100
#  - 0s - loss: 175.7028
# Epoch 21/100
#  - 0s - loss: 171.2736
# Epoch 22/100
#  - 0s - loss: 168.4381
# Epoch 23/100
#  - 0s - loss: 165.3460
# Epoch 24/100
#  - 0s - loss: 162.3829
# Epoch 25/100
#  - 0s - loss: 159.7624
# Epoch 26/100
#  - 0s - loss: 157.1666
# Epoch 27/100
#  - 0s - loss: 155.2330
# Epoch 28/100
#  - 0s - loss: 152.5752
# Epoch 29/100
#  - 0s - loss: 151.0052
# Epoch 30/100
#  - 0s - loss: 148.6689
# Epoch 31/100
#  - 0s - loss: 145.9203
# Epoch 32/100
#  - 0s - loss: 145.2574
# Epoch 33/100
#  - 0s - loss: 144.0727
# Epoch 34/100
#  - 0s - loss: 140.2999
# Epoch 35/100
#  - 0s - loss: 140.1490
# Epoch 36/100
#  - 0s - loss: 139.0706
# Epoch 37/100
#  - 0s - loss: 136.0821
# Epoch 38/100
#  - 0s - loss: 134.0971
# Epoch 39/100
#  - 0s - loss: 132.0481
# Epoch 40/100
#  - 0s - loss: 130.1810
# Epoch 41/100
#  - 0s - loss: 128.1671
# Epoch 42/100
#  - 0s - loss: 126.4660
# Epoch 43/100
#  - 0s - loss: 124.3888
# Epoch 44/100
#  - 0s - loss: 122.3596
# Epoch 45/100
#  - 0s - loss: 120.3122
# Epoch 46/100
#  - 0s - loss: 118.3767
# Epoch 47/100
#  - 0s - loss: 116.1526
# Epoch 48/100
#  - 0s - loss: 113.8215
# Epoch 49/100
#  - 0s - loss: 111.5807
# Epoch 50/100
#  - 0s - loss: 109.8051
# Epoch 51/100
#  - 0s - loss: 107.7067
# Epoch 52/100
#  - 0s - loss: 104.5051
# Epoch 53/100
#  - 0s - loss: 102.1761
# Epoch 54/100
#  - 0s - loss: 99.5336
# Epoch 55/100
#  - 0s - loss: 97.2772
# Epoch 56/100
#  - 0s - loss: 94.9099
# Epoch 57/100
#  - 0s - loss: 92.9145
# Epoch 58/100
#  - 0s - loss: 90.3411
# Epoch 59/100
#  - 0s - loss: 87.8397
# Epoch 60/100
#  - 0s - loss: 85.9000
# Epoch 61/100
#  - 0s - loss: 83.5728
# Epoch 62/100
#  - 0s - loss: 81.4398
# Epoch 63/100
#  - 0s - loss: 78.4012
# Epoch 64/100
#  - 0s - loss: 77.1519
# Epoch 65/100
#  - 0s - loss: 74.5239
# Epoch 66/100
#  - 0s - loss: 72.3306
# Epoch 67/100
#  - 0s - loss: 70.9359
# Epoch 68/100
#  - 0s - loss: 68.2166
# Epoch 69/100
#  - 0s - loss: 66.3232
# Epoch 70/100
#  - 0s - loss: 65.1936
# Epoch 71/100
#  - 0s - loss: 62.5842
# Epoch 72/100
#  - 0s - loss: 60.9157
# Epoch 73/100
#  - 0s - loss: 59.1402
# Epoch 74/100
#  - 0s - loss: 57.2875
# Epoch 75/100
#  - 0s - loss: 55.8288
# Epoch 76/100
#  - 0s - loss: 54.5412
# Epoch 77/100
#  - 0s - loss: 53.4477
# Epoch 78/100
#  - 0s - loss: 52.3302
# Epoch 79/100
#  - 0s - loss: 51.0797
# Epoch 80/100
#  - 0s - loss: 49.6143
# Epoch 81/100
#  - 0s - loss: 48.6548
# Epoch 82/100
#  - 0s - loss: 47.3507
# Epoch 83/100
#  - 0s - loss: 46.6158
# Epoch 84/100
#  - 0s - loss: 45.5753
# Epoch 85/100
#  - 0s - loss: 45.0469
# Epoch 86/100
#  - 0s - loss: 44.1977
# Epoch 87/100
#  - 0s - loss: 43.2351
# Epoch 88/100
#  - 0s - loss: 42.7600
# Epoch 89/100
#  - 0s - loss: 41.9621
# Epoch 90/100
#  - 0s - loss: 41.3644
# Epoch 91/100
#  - 0s - loss: 40.7611
# Epoch 92/100
#  - 0s - loss: 40.0158
# Epoch 93/100
#  - 0s - loss: 39.8578
# Epoch 94/100
#  - 0s - loss: 39.4026
# Epoch 95/100
#  - 0s - loss: 39.6229
# Epoch 96/100
#  - 0s - loss: 39.1275
# Epoch 97/100
#  - 0s - loss: 39.4383
# Epoch 98/100
#  - 0s - loss: 37.8954
# Epoch 99/100
#  - 0s - loss: 37.2655
# Epoch 100/100
#  - 0s - loss: 36.3074
# Executing op __inference_keras_scratch_graph_34998 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op __inference_keras_scratch_graph_35065 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op RandomUniform in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op RandomUniform in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op RandomUniform in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op RandomUniform in device /job:localhost/replica:0/task:0/device:GPU:0
# Epoch 1/100
# Executing op __inference_keras_scratch_graph_36155 in device /job:localhost/replica:0/task:0/device:GPU:0
#  - 0s - loss: 1554.1179
# Epoch 2/100
#  - 0s - loss: 1509.8728
# Epoch 3/100
#  - 0s - loss: 1445.5703
# Epoch 4/100
#  - 0s - loss: 1346.9628
# Epoch 5/100
#  - 0s - loss: 1201.5246
# Epoch 6/100
#  - 0s - loss: 994.7932
# Epoch 7/100
#  - 0s - loss: 739.4652
# Epoch 8/100
#  - 0s - loss: 482.6037
# Epoch 9/100
#  - 0s - loss: 326.7433
# Epoch 10/100
#  - 0s - loss: 276.6931
# Epoch 11/100
#  - 0s - loss: 251.0157
# Epoch 12/100
#  - 0s - loss: 229.9174
# Epoch 13/100
#  - 0s - loss: 217.1165
# Epoch 14/100
#  - 0s - loss: 207.7606
# Epoch 15/100
#  - 0s - loss: 200.6792
# Epoch 16/100
#  - 0s - loss: 194.7190
# Epoch 17/100
#  - 0s - loss: 189.1310
# Epoch 18/100
#  - 0s - loss: 183.6247
# Epoch 19/100
#  - 0s - loss: 179.0776
# Epoch 20/100
#  - 0s - loss: 175.2402
# Epoch 21/100
#  - 0s - loss: 171.3724
# Epoch 22/100
#  - 0s - loss: 167.4560
# Epoch 23/100
#  - 0s - loss: 163.9101
# Epoch 24/100
#  - 0s - loss: 161.0493
# Epoch 25/100
#  - 0s - loss: 157.3291
# Epoch 26/100
#  - 0s - loss: 154.5853
# Epoch 27/100
#  - 0s - loss: 151.7664
# Epoch 28/100
#  - 0s - loss: 148.6706
# Epoch 29/100
#  - 0s - loss: 145.5521
# Epoch 30/100
#  - 0s - loss: 142.9718
# Epoch 31/100
#  - 0s - loss: 140.5187
# Epoch 32/100
#  - 0s - loss: 137.3956
# Epoch 33/100
#  - 0s - loss: 135.3614
# Epoch 34/100
#  - 0s - loss: 132.5896
# Epoch 35/100
#  - 0s - loss: 130.2007
# Epoch 36/100
#  - 0s - loss: 127.5470
# Epoch 37/100
#  - 0s - loss: 125.9426
# Epoch 38/100
#  - 0s - loss: 122.9380
# Epoch 39/100
#  - 0s - loss: 120.2424
# Epoch 40/100
#  - 0s - loss: 117.5783
# Epoch 41/100
#  - 0s - loss: 115.7376
# Epoch 42/100
#  - 0s - loss: 112.0831
# Epoch 43/100
#  - 0s - loss: 110.2764
# Epoch 44/100
#  - 0s - loss: 107.2636
# Epoch 45/100
#  - 0s - loss: 104.6798
# Epoch 46/100
#  - 0s - loss: 101.8429
# Epoch 47/100
#  - 0s - loss: 99.4973
# Epoch 48/100
#  - 0s - loss: 97.6118
# Epoch 49/100
#  - 0s - loss: 94.8953
# Epoch 50/100
#  - 0s - loss: 92.8819
# Epoch 51/100
#  - 0s - loss: 90.8901
# Epoch 52/100
#  - 0s - loss: 88.6061
# Epoch 53/100
#  - 0s - loss: 86.4142
# Epoch 54/100
#  - 0s - loss: 84.7895
# Epoch 55/100
#  - 0s - loss: 82.5818
# Epoch 56/100
#  - 0s - loss: 80.7767
# Epoch 57/100
#  - 0s - loss: 78.5647
# Epoch 58/100
#  - 0s - loss: 76.7994
# Epoch 59/100
#  - 0s - loss: 75.1431
# Epoch 60/100
#  - 0s - loss: 73.4544
# Epoch 61/100
#  - 0s - loss: 72.1520
# Epoch 62/100
#  - 0s - loss: 69.6322
# Epoch 63/100
#  - 0s - loss: 69.2047
# Epoch 64/100
#  - 0s - loss: 66.6531
# Epoch 65/100
#  - 0s - loss: 65.3990
# Epoch 66/100
#  - 0s - loss: 64.0987
# Epoch 67/100
#  - 0s - loss: 62.2533
# Epoch 68/100
#  - 0s - loss: 61.9002
# Epoch 69/100
#  - 0s - loss: 59.8137
# Epoch 70/100
#  - 0s - loss: 58.7142
# Epoch 71/100
#  - 0s - loss: 57.5505
# Epoch 72/100
#  - 0s - loss: 56.0685
# Epoch 73/100
#  - 0s - loss: 55.0528
# Epoch 74/100
#  - 0s - loss: 53.5025
# Epoch 75/100
#  - 0s - loss: 52.8214
# Epoch 76/100
#  - 0s - loss: 51.7733
# Epoch 77/100
#  - 0s - loss: 50.4060
# Epoch 78/100
#  - 0s - loss: 49.6064
# Epoch 79/100
#  - 0s - loss: 48.4540
# Epoch 80/100
#  - 0s - loss: 47.5905
# Epoch 81/100
#  - 0s - loss: 46.6886
# Epoch 82/100
#  - 0s - loss: 46.2337
# Epoch 83/100
#  - 0s - loss: 45.5591
# Epoch 84/100
#  - 0s - loss: 43.9635
# Epoch 85/100
#  - 0s - loss: 43.2642
# Epoch 86/100
#  - 0s - loss: 42.4084
# Epoch 87/100
#  - 0s - loss: 42.5050
# Epoch 88/100
#  - 0s - loss: 40.9519
# Epoch 89/100
#  - 0s - loss: 40.7123
# Epoch 90/100
#  - 0s - loss: 39.4943
# Epoch 91/100
#  - 0s - loss: 39.0250
# Epoch 92/100
#  - 0s - loss: 38.2243
# Epoch 93/100
#  - 0s - loss: 37.7237
# Epoch 94/100
#  - 0s - loss: 37.1266
# Epoch 95/100
#  - 0s - loss: 36.7472
# Epoch 96/100
#  - 0s - loss: 35.7983
# Epoch 97/100
#  - 0s - loss: 35.3913
# Epoch 98/100
#  - 0s - loss: 34.5833
# Epoch 99/100
#  - 0s - loss: 34.3259
# Epoch 100/100
#  - 0s - loss: 34.6706
# Executing op __inference_keras_scratch_graph_39386 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op __inference_keras_scratch_graph_39453 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op RandomUniform in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op RandomUniform in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op RandomUniform in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op RandomUniform in device /job:localhost/replica:0/task:0/device:GPU:0
# Epoch 1/100
# Executing op __inference_keras_scratch_graph_40543 in device /job:localhost/replica:0/task:0/device:GPU:0
#  - 0s - loss: 1561.2602
# Epoch 2/100
#  - 0s - loss: 1511.0907
# Epoch 3/100
#  - 0s - loss: 1444.0121
# Epoch 4/100
#  - 0s - loss: 1344.3871
# Epoch 5/100
#  - 0s - loss: 1194.9307
# Epoch 6/100
#  - 0s - loss: 982.7623
# Epoch 7/100
#  - 0s - loss: 716.7869
# Epoch 8/100
#  - 0s - loss: 439.0892
# Epoch 9/100
#  - 0s - loss: 268.6332
# Epoch 10/100
#  - 0s - loss: 233.5918
# Epoch 11/100
#  - 0s - loss: 229.1140
# Epoch 12/100
#  - 0s - loss: 209.8008
# Epoch 13/100
#  - 0s - loss: 199.2799
# Epoch 14/100
#  - 0s - loss: 193.4456
# Epoch 15/100
#  - 0s - loss: 187.0197
# Epoch 16/100
#  - 0s - loss: 181.9635
# Epoch 17/100
#  - 0s - loss: 177.7611
# Epoch 18/100
#  - 0s - loss: 174.3168
# Epoch 19/100
#  - 0s - loss: 170.4476
# Epoch 20/100
#  - 0s - loss: 167.2508
# Epoch 21/100
#  - 0s - loss: 164.4090
# Epoch 22/100
#  - 0s - loss: 161.1933
# Epoch 23/100
#  - 0s - loss: 158.7312
# Epoch 24/100
#  - 0s - loss: 156.1088
# Epoch 25/100
#  - 0s - loss: 153.8193
# Epoch 26/100
#  - 0s - loss: 151.1645
# Epoch 27/100
#  - 0s - loss: 148.7064
# Epoch 28/100
#  - 0s - loss: 146.9661
# Epoch 29/100
#  - 0s - loss: 144.1235
# Epoch 30/100
#  - 0s - loss: 141.9080
# Epoch 31/100
#  - 0s - loss: 140.3013
# Epoch 32/100
#  - 0s - loss: 137.4924
# Epoch 33/100
#  - 0s - loss: 135.1077
# Epoch 34/100
#  - 0s - loss: 132.7808
# Epoch 35/100
#  - 0s - loss: 130.3591
# Epoch 36/100
#  - 0s - loss: 128.1396
# Epoch 37/100
#  - 0s - loss: 125.1167
# Epoch 38/100
#  - 0s - loss: 123.1278
# Epoch 39/100
#  - 0s - loss: 120.4623
# Epoch 40/100
#  - 0s - loss: 117.9873
# Epoch 41/100
#  - 0s - loss: 115.6905
# Epoch 42/100
#  - 0s - loss: 112.5097
# Epoch 43/100
#  - 0s - loss: 110.9383
# Epoch 44/100
#  - 0s - loss: 107.8394
# Epoch 45/100
#  - 0s - loss: 105.2886
# Epoch 46/100
#  - 0s - loss: 102.9668
# Epoch 47/100
#  - 0s - loss: 99.7551
# Epoch 48/100
#  - 0s - loss: 97.4303
# Epoch 49/100
#  - 0s - loss: 95.0502
# Epoch 50/100
#  - 0s - loss: 92.6874
# Epoch 51/100
#  - 0s - loss: 90.4769
# Epoch 52/100
#  - 0s - loss: 88.0944
# Epoch 53/100
#  - 0s - loss: 86.0063
# Epoch 54/100
#  - 0s - loss: 84.0619
# Epoch 55/100
#  - 0s - loss: 81.8171
# Epoch 56/100
#  - 0s - loss: 80.1763
# Epoch 57/100
#  - 0s - loss: 78.8969
# Epoch 58/100
#  - 0s - loss: 76.1190
# Epoch 59/100
#  - 0s - loss: 75.8112
# Epoch 60/100
#  - 0s - loss: 72.9267
# Epoch 61/100
#  - 0s - loss: 71.7838
# Epoch 62/100
#  - 0s - loss: 70.0225
# Epoch 63/100
#  - 0s - loss: 68.2465
# Epoch 64/100
#  - 0s - loss: 66.5477
# Epoch 65/100
#  - 0s - loss: 65.5730
# Epoch 66/100
#  - 0s - loss: 63.5035
# Epoch 67/100
#  - 0s - loss: 62.4521
# Epoch 68/100
#  - 0s - loss: 62.1551
# Epoch 69/100
#  - 0s - loss: 60.2386
# Epoch 70/100
#  - 0s - loss: 58.8010
# Epoch 71/100
#  - 0s - loss: 57.9080
# Epoch 72/100
#  - 0s - loss: 56.7111
# Epoch 73/100
#  - 0s - loss: 55.4400
# Epoch 74/100
#  - 0s - loss: 54.2033
# Epoch 75/100
#  - 0s - loss: 53.2542
# Epoch 76/100
#  - 0s - loss: 52.0842
# Epoch 77/100
#  - 0s - loss: 51.5276
# Epoch 78/100
#  - 0s - loss: 50.0921
# Epoch 79/100
#  - 0s - loss: 49.7007
# Epoch 80/100
#  - 0s - loss: 49.0933
# Epoch 81/100
#  - 0s - loss: 48.3791
# Epoch 82/100
#  - 0s - loss: 47.4515
# Epoch 83/100
#  - 0s - loss: 45.9658
# Epoch 84/100
#  - 0s - loss: 45.3191
# Epoch 85/100
#  - 0s - loss: 45.0828
# Epoch 86/100
#  - 0s - loss: 43.7669
# Epoch 87/100
#  - 0s - loss: 43.0470
# Epoch 88/100
#  - 0s - loss: 42.3625
# Epoch 89/100
#  - 0s - loss: 41.7138
# Epoch 90/100
#  - 0s - loss: 41.3371
# Epoch 91/100
#  - 0s - loss: 40.2615
# Epoch 92/100
#  - 0s - loss: 40.4507
# Epoch 93/100
#  - 0s - loss: 39.6891
# Epoch 94/100
#  - 0s - loss: 39.6242
# Epoch 95/100
#  - 0s - loss: 39.5966
# Epoch 96/100
#  - 0s - loss: 39.0697
# Epoch 97/100
#  - 0s - loss: 37.9263
# Epoch 98/100
#  - 0s - loss: 36.8130
# Epoch 99/100
#  - 0s - loss: 36.4162
# Epoch 100/100
#  - 0s - loss: 36.0961
# Executing op __inference_keras_scratch_graph_43774 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op __inference_keras_scratch_graph_43841 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op RandomUniform in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op RandomUniform in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op RandomUniform in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op RandomUniform in device /job:localhost/replica:0/task:0/device:GPU:0
# Epoch 1/100
# Executing op __inference_keras_scratch_graph_44931 in device /job:localhost/replica:0/task:0/device:GPU:0
#  - 0s - loss: 1583.7766
# Epoch 2/100
#  - 0s - loss: 1550.6640
# Epoch 3/100
#  - 0s - loss: 1511.2094
# Epoch 4/100
#  - 0s - loss: 1453.0719
# Epoch 5/100
#  - 0s - loss: 1361.7676
# Epoch 6/100
#  - 0s - loss: 1216.8066
# Epoch 7/100
#  - 0s - loss: 1009.7270
# Epoch 8/100
#  - 0s - loss: 740.0940
# Epoch 9/100
#  - 0s - loss: 473.8519
# Epoch 10/100
#  - 0s - loss: 295.8291
# Epoch 11/100
#  - 0s - loss: 265.5891
# Epoch 12/100
#  - 0s - loss: 259.0515
# Epoch 13/100
#  - 0s - loss: 233.0871
# Epoch 14/100
#  - 0s - loss: 222.6197
# Epoch 15/100
#  - 0s - loss: 216.4064
# Epoch 16/100
#  - 0s - loss: 207.6992
# Epoch 17/100
#  - 0s - loss: 203.0038
# Epoch 18/100
#  - 0s - loss: 197.2757
# Epoch 19/100
#  - 0s - loss: 191.6597
# Epoch 20/100
#  - 0s - loss: 187.4776
# Epoch 21/100
#  - 0s - loss: 183.2139
# Epoch 22/100
#  - 0s - loss: 180.3617
# Epoch 23/100
#  - 0s - loss: 176.0668
# Epoch 24/100
#  - 0s - loss: 172.6642
# Epoch 25/100
#  - 0s - loss: 169.6417
# Epoch 26/100
#  - 0s - loss: 166.6646
# Epoch 27/100
#  - 0s - loss: 164.4117
# Epoch 28/100
#  - 0s - loss: 161.9059
# Epoch 29/100
#  - 0s - loss: 159.1069
# Epoch 30/100
#  - 0s - loss: 157.0981
# Epoch 31/100
#  - 0s - loss: 154.7693
# Epoch 32/100
#  - 0s - loss: 152.6555
# Epoch 33/100
#  - 0s - loss: 151.3293
# Epoch 34/100
#  - 0s - loss: 149.2716
# Epoch 35/100
#  - 0s - loss: 147.6607
# Epoch 36/100
#  - 0s - loss: 145.6188
# Epoch 37/100
#  - 0s - loss: 144.0817
# Epoch 38/100
#  - 0s - loss: 142.6098
# Epoch 39/100
#  - 0s - loss: 141.0470
# Epoch 40/100
#  - 0s - loss: 139.6228
# Epoch 41/100
#  - 0s - loss: 138.5718
# Epoch 42/100
#  - 0s - loss: 137.2842
# Epoch 43/100
#  - 0s - loss: 135.8782
# Epoch 44/100
#  - 0s - loss: 134.7540
# Epoch 45/100
#  - 0s - loss: 133.9875
# Epoch 46/100
#  - 0s - loss: 132.2558
# Epoch 47/100
#  - 0s - loss: 131.1709
# Epoch 48/100
#  - 0s - loss: 130.1367
# Epoch 49/100
#  - 0s - loss: 129.3393
# Epoch 50/100
#  - 0s - loss: 128.1658
# Epoch 51/100
#  - 0s - loss: 126.9347
# Epoch 52/100
#  - 0s - loss: 125.9551
# Epoch 53/100
#  - 0s - loss: 125.0360
# Epoch 54/100
#  - 0s - loss: 123.6798
# Epoch 55/100
#  - 0s - loss: 123.4892
# Epoch 56/100
#  - 0s - loss: 121.7549
# Epoch 57/100
#  - 0s - loss: 120.8156
# Epoch 58/100
#  - 0s - loss: 119.6695
# Epoch 59/100
#  - 0s - loss: 118.9698
# Epoch 60/100
#  - 0s - loss: 117.7743
# Epoch 61/100
#  - 0s - loss: 116.2016
# Epoch 62/100
#  - 0s - loss: 114.5277
# Epoch 63/100
#  - 0s - loss: 113.8092
# Epoch 64/100
#  - 0s - loss: 111.8918
# Epoch 65/100
#  - 0s - loss: 110.8208
# Epoch 66/100
#  - 0s - loss: 109.1172
# Epoch 67/100
#  - 0s - loss: 107.2787
# Epoch 68/100
#  - 0s - loss: 105.9844
# Epoch 69/100
#  - 0s - loss: 104.3406
# Epoch 70/100
#  - 0s - loss: 102.7359
# Epoch 71/100
#  - 0s - loss: 101.1215
# Epoch 72/100
#  - 0s - loss: 98.5890
# Epoch 73/100
#  - 0s - loss: 97.5173
# Epoch 74/100
#  - 0s - loss: 95.6644
# Epoch 75/100
#  - 0s - loss: 93.7532
# Epoch 76/100
#  - 0s - loss: 92.2045
# Epoch 77/100
#  - 0s - loss: 89.9611
# Epoch 78/100
#  - 0s - loss: 88.5557
# Epoch 79/100
#  - 0s - loss: 86.5960
# Epoch 80/100
#  - 0s - loss: 84.6073
# Epoch 81/100
#  - 0s - loss: 83.2342
# Epoch 82/100
#  - 0s - loss: 80.9638
# Epoch 83/100
#  - 0s - loss: 79.1913
# Epoch 84/100
#  - 0s - loss: 77.4950
# Epoch 85/100
#  - 0s - loss: 75.8078
# Epoch 86/100
#  - 0s - loss: 74.4722
# Epoch 87/100
#  - 0s - loss: 72.6989
# Epoch 88/100
#  - 0s - loss: 70.5856
# Epoch 89/100
#  - 0s - loss: 68.6618
# Epoch 90/100
#  - 0s - loss: 68.2423
# Epoch 91/100
#  - 0s - loss: 66.1205
# Epoch 92/100
#  - 0s - loss: 64.0006
# Epoch 93/100
#  - 0s - loss: 62.5608
# Epoch 94/100
#  - 0s - loss: 61.1000
# Epoch 95/100
#  - 0s - loss: 59.5386
# Epoch 96/100
#  - 0s - loss: 58.6745
# Epoch 97/100
#  - 0s - loss: 57.1830
# Epoch 98/100
#  - 0s - loss: 55.5764
# Epoch 99/100
#  - 0s - loss: 55.0224
# Epoch 100/100
#  - 0s - loss: 53.2135
# Executing op __inference_keras_scratch_graph_48162 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op __inference_keras_scratch_graph_48229 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op RandomUniform in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op RandomUniform in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op RandomUniform in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op RandomUniform in device /job:localhost/replica:0/task:0/device:GPU:0
# Epoch 1/100
# ...
# Epoch 12/100
#  - 0s - loss: 210.5735
# Epoch 13/100
#  - 0s - loss: 206.4610
# Epoch 14/100
#  - 0s - loss: 198.8695
# Epoch 15/100
#  - 0s - loss: 193.8266
# Epoch 16/100
#  - 0s - loss: 187.8427
# Epoch 17/100
#  - 0s - loss: 183.8351
# Epoch 18/100
#  - 0s - loss: 180.0804
# Epoch 19/100
#  - 0s - loss: 176.9272
# Epoch 20/100
#  - 0s - loss: 173.5837
# Epoch 21/100
#  - 0s - loss: 170.1635
# Epoch 22/100
#  - 0s - loss: 167.9896
# Epoch 23/100
#  - 0s - loss: 165.2397
# Epoch 24/100
#  - 0s - loss: 162.7444
# Epoch 25/100
#  - 0s - loss: 160.7241
# Epoch 26/100
#  - 0s - loss: 158.6276
# Epoch 27/100
#  - 0s - loss: 156.6576
# Epoch 28/100
#  - 0s - loss: 154.5739
# Epoch 29/100
#  - 0s - loss: 152.9867
# Epoch 30/100
#  - 0s - loss: 151.5370
# Epoch 31/100
#  - 0s - loss: 149.0434
# Epoch 32/100
#  - 0s - loss: 147.4093
# Epoch 33/100
#  - 0s - loss: 145.3413
# Epoch 34/100
#  - 0s - loss: 143.9662
# Epoch 35/100
#  - 0s - loss: 142.3001
# Epoch 36/100
#  - 0s - loss: 140.0887
# Epoch 37/100
#  - 0s - loss: 138.6153
# Epoch 38/100
#  - 0s - loss: 136.9265
# Epoch 39/100
#  - 0s - loss: 134.7653
# Epoch 40/100
#  - 0s - loss: 133.1118
# Epoch 41/100
#  - 0s - loss: 131.0530
# Epoch 42/100
#  - 0s - loss: 129.4011
# Epoch 43/100
#  - 0s - loss: 127.2814
# Epoch 44/100
#  - 0s - loss: 125.5758
# Epoch 45/100
#  - 0s - loss: 122.4699
# Epoch 46/100
#  - 0s - loss: 120.3452
# Epoch 47/100
#  - 0s - loss: 119.6617
# Epoch 48/100
#  - 0s - loss: 115.0542
# Epoch 49/100
#  - 0s - loss: 113.7397
# Epoch 50/100
#  - 0s - loss: 110.7598
# Epoch 51/100
#  - 0s - loss: 108.3247
# Epoch 52/100
#  - 0s - loss: 105.8956
# Epoch 53/100
#  - 0s - loss: 102.8230
# Epoch 54/100
#  - 0s - loss: 100.1181
# Epoch 55/100
#  - 0s - loss: 97.5087
# Epoch 56/100
#  - 0s - loss: 94.5822
# Epoch 57/100
#  - 0s - loss: 91.8841
# Epoch 58/100
#  - 0s - loss: 89.2673
# Epoch 59/100
#  - 0s - loss: 86.3503
# Epoch 60/100
#  - 0s - loss: 83.4183
# Epoch 61/100
#  - 0s - loss: 81.0462
# Epoch 62/100
#  - 0s - loss: 78.3562
# Epoch 63/100
#  - 0s - loss: 75.4534
# Epoch 64/100
#  - 0s - loss: 73.5589
# Epoch 65/100
#  - 0s - loss: 71.2202
# Epoch 66/100
#  - 0s - loss: 68.6243
# Epoch 67/100
#  - 0s - loss: 66.6366
# Epoch 68/100
#  - 0s - loss: 64.8162
# Epoch 69/100
#  - 0s - loss: 63.3723
# Epoch 70/100
#  - 0s - loss: 62.0310
# Epoch 71/100
#  - 0s - loss: 59.2555
# Epoch 72/100
#  - 0s - loss: 58.0069
# Epoch 73/100
#  - 0s - loss: 56.3998
# Epoch 74/100
#  - 0s - loss: 55.3725
# Epoch 75/100
#  - 0s - loss: 53.7040
# Epoch 76/100
#  - 0s - loss: 52.1814
# Epoch 77/100
#  - 0s - loss: 51.1807
# Epoch 78/100
#  - 0s - loss: 50.0124
# Epoch 79/100
#  - 0s - loss: 49.4909
# Epoch 80/100
#  - 0s - loss: 47.7604
# Epoch 81/100
#  - 0s - loss: 47.2141
# Epoch 82/100
#  - 0s - loss: 45.9201
# Epoch 83/100
#  - 0s - loss: 44.9945
# Epoch 84/100
#  - 0s - loss: 44.1163
# Epoch 85/100
#  - 0s - loss: 43.4863
# Epoch 86/100
#  - 0s - loss: 42.2793
# Epoch 87/100
#  - 0s - loss: 42.1853
# Epoch 88/100
#  - 0s - loss: 41.5729
# Epoch 89/100
#  - 0s - loss: 40.2514
# Epoch 90/100
#  - 0s - loss: 39.7899
# Epoch 91/100
#  - 0s - loss: 39.9926
# Epoch 92/100
#  - 0s - loss: 38.8761
# Epoch 93/100
#  - 0s - loss: 38.3107
# Epoch 94/100
#  - 0s - loss: 38.4055
# Epoch 95/100
#  - 0s - loss: 37.2121
# Epoch 96/100
#  - 0s - loss: 37.0923
# Epoch 97/100
#  - 0s - loss: 36.7681
# Epoch 98/100
#  - 0s - loss: 36.7459
# Epoch 99/100
#  - 0s - loss: 35.7303
# Epoch 100/100
#  - 0s - loss: 35.6863
# Executing op __inference_keras_scratch_graph_206130 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op __inference_keras_scratch_graph_206197 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op RandomUniform in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op RandomUniform in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op RandomUniform in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op RandomUniform in device /job:localhost/replica:0/task:0/device:GPU:0
# Epoch 1/100
# Executing op __inference_keras_scratch_graph_207287 in device /job:localhost/replica:0/task:0/device:GPU:0
#  - 0s - loss: 1582.2615
# Epoch 2/100
#  - 0s - loss: 1547.9472
# Epoch 3/100
#  - 0s - loss: 1501.4026
# Epoch 4/100
#  - 0s - loss: 1431.6035
# Epoch 5/100
#  - 0s - loss: 1326.1013
# Epoch 6/100
#  - 0s - loss: 1168.2486
# Epoch 7/100
#  - 0s - loss: 948.6124
# Epoch 8/100
#  - 0s - loss: 679.7240
# Epoch 9/100
#  - 0s - loss: 432.1485
# Epoch 10/100
#  - 0s - loss: 293.2157
# Epoch 11/100
#  - 0s - loss: 268.8870
# Epoch 12/100
#  - 0s - loss: 253.6844
# Epoch 13/100
#  - 0s - loss: 230.4252
# Epoch 14/100
#  - 0s - loss: 218.2525
# Epoch 15/100
#  - 0s - loss: 210.3707
# Epoch 16/100
#  - 0s - loss: 203.6101
# Epoch 17/100
#  - 0s - loss: 197.2332
# Epoch 18/100
#  - 0s - loss: 192.1315
# Epoch 19/100
#  - 0s - loss: 187.2885
# Epoch 20/100
#  - 0s - loss: 182.5924
# Epoch 21/100
#  - 0s - loss: 178.9629
# Epoch 22/100
#  - 0s - loss: 175.8563
# Epoch 23/100
#  - 0s - loss: 171.9868
# Epoch 24/100
#  - 0s - loss: 168.8139
# Epoch 25/100
#  - 0s - loss: 166.6605
# Epoch 26/100
#  - 0s - loss: 164.4879
# Epoch 27/100
#  - 0s - loss: 161.4362
# Epoch 28/100
#  - 0s - loss: 159.3848
# Epoch 29/100
#  - 0s - loss: 157.0337
# Epoch 30/100
#  - 0s - loss: 155.5558
# Epoch 31/100
#  - 0s - loss: 152.7898
# Epoch 32/100
#  - 0s - loss: 150.8975
# Epoch 33/100
#  - 0s - loss: 149.0582
# Epoch 34/100
#  - 0s - loss: 148.6426
# Epoch 35/100
#  - 0s - loss: 145.8609
# Epoch 36/100
#  - 0s - loss: 144.9808
# Epoch 37/100
#  - 0s - loss: 143.2118
# Epoch 38/100
#  - 0s - loss: 141.9782
# Epoch 39/100
#  - 0s - loss: 140.0106
# Epoch 40/100
#  - 0s - loss: 139.7120
# Epoch 41/100
#  - 0s - loss: 137.9909
# Epoch 42/100
#  - 0s - loss: 136.2358
# Epoch 43/100
#  - 0s - loss: 135.0966
# Epoch 44/100
#  - 0s - loss: 133.8074
# Epoch 45/100
#  - 0s - loss: 132.3891
# Epoch 46/100
#  - 0s - loss: 131.0524
# Epoch 47/100
#  - 0s - loss: 129.6607
# Epoch 48/100
#  - 0s - loss: 128.1006
# Epoch 49/100
#  - 0s - loss: 127.6420
# Epoch 50/100
#  - 0s - loss: 125.8304
# Epoch 51/100
#  - 0s - loss: 124.1057
# Epoch 52/100
#  - 0s - loss: 122.6324
# Epoch 53/100
#  - 0s - loss: 121.4038
# Epoch 54/100
#  - 0s - loss: 120.5250
# Epoch 55/100
#  - 0s - loss: 118.5932
# Epoch 56/100
#  - 0s - loss: 116.7898
# Epoch 57/100
#  - 0s - loss: 115.3369
# Epoch 58/100
#  - 0s - loss: 113.3931
# Epoch 59/100
#  - 0s - loss: 111.7654
# Epoch 60/100
#  - 0s - loss: 109.8280
# Epoch 61/100
#  - 0s - loss: 108.2109
# Epoch 62/100
#  - 0s - loss: 106.1199
# Epoch 63/100
#  - 0s - loss: 104.4696
# Epoch 64/100
#  - 0s - loss: 102.6936
# Epoch 65/100
#  - 0s - loss: 100.1991
# Epoch 66/100
#  - 0s - loss: 98.2514
# Epoch 67/100
#  - 0s - loss: 96.1762
# Epoch 68/100
#  - 0s - loss: 93.8015
# Epoch 69/100
#  - 0s - loss: 91.8138
# Epoch 70/100
#  - 0s - loss: 89.9512
# Epoch 71/100
#  - 0s - loss: 87.5375
# Epoch 72/100
#  - 0s - loss: 84.8807
# Epoch 73/100
#  - 0s - loss: 82.8518
# Epoch 74/100
#  - 0s - loss: 81.2246
# Epoch 75/100
#  - 0s - loss: 78.2541
# Epoch 76/100
#  - 0s - loss: 76.0807
# Epoch 77/100
#  - 0s - loss: 74.4992
# Epoch 78/100
#  - 0s - loss: 72.1276
# Epoch 79/100
#  - 0s - loss: 70.1663
# Epoch 80/100
#  - 0s - loss: 68.5958
# Epoch 81/100
#  - 0s - loss: 67.3575
# Epoch 82/100
#  - 0s - loss: 65.4329
# Epoch 83/100
#  - 0s - loss: 63.8556
# Epoch 84/100
#  - 0s - loss: 62.4500
# Epoch 85/100
#  - 0s - loss: 60.8315
# Epoch 86/100
#  - 0s - loss: 59.7521
# Epoch 87/100
#  - 0s - loss: 58.5901
# Epoch 88/100
#  - 0s - loss: 57.3250
# Epoch 89/100
#  - 0s - loss: 56.2627
# Epoch 90/100
#  - 0s - loss: 55.3614
# Epoch 91/100
#  - 0s - loss: 53.6625
# Epoch 92/100
#  - 0s - loss: 52.3261
# Epoch 93/100
#  - 0s - loss: 51.0287
# Epoch 94/100
#  - 0s - loss: 50.2865
# Epoch 95/100
#  - 0s - loss: 48.8644
# Epoch 96/100
#  - 0s - loss: 47.9896
# Epoch 97/100
#  - 0s - loss: 47.3312
# Epoch 98/100
#  - 0s - loss: 46.4225
# Epoch 99/100
#  - 0s - loss: 45.0865
# Epoch 100/100
#  - 0s - loss: 44.5509
# Executing op __inference_keras_scratch_graph_210518 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op __inference_keras_scratch_graph_210585 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op RandomUniform in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op RandomUniform in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op RandomUniform in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op RandomUniform in device /job:localhost/replica:0/task:0/device:GPU:0
# Epoch 1/100
# Executing op __inference_keras_scratch_graph_211675 in device /job:localhost/replica:0/task:0/device:GPU:0
#  - 0s - loss: 1576.4299
# Epoch 2/100
#  - 0s - loss: 1533.8242
# Epoch 3/100
#  - 0s - loss: 1475.3830
# Epoch 4/100
#  - 0s - loss: 1390.2639
# Epoch 5/100
#  - 0s - loss: 1265.2466
# Epoch 6/100
#  - 0s - loss: 1073.9608
# Epoch 7/100
#  - 0s - loss: 825.5021
# Epoch 8/100
#  - 0s - loss: 537.4477
# Epoch 9/100
#  - 0s - loss: 313.7276
# Epoch 10/100
#  - 0s - loss: 247.1231
# Epoch 11/100
#  - 0s - loss: 253.8490
# Epoch 12/100
#  - 0s - loss: 231.4955
# Epoch 13/100
#  - 0s - loss: 219.7734
# Epoch 14/100
#  - 0s - loss: 213.7208
# Epoch 15/100
#  - 0s - loss: 206.8062
# Epoch 16/100
#  - 0s - loss: 201.3535
# Epoch 17/100
#  - 0s - loss: 196.6885
# Epoch 18/100
#  - 0s - loss: 192.5293
# Epoch 19/100
#  - 0s - loss: 188.1310
# Epoch 20/100
#  - 0s - loss: 184.4923
# Epoch 21/100
#  - 0s - loss: 181.1449
# Epoch 22/100
#  - 0s - loss: 178.1530
# Epoch 23/100
#  - 0s - loss: 174.6128
# Epoch 24/100
#  - 0s - loss: 171.9455
# Epoch 25/100
#  - 0s - loss: 169.2014
# Epoch 26/100
#  - 0s - loss: 166.4366
# Epoch 27/100
#  - 0s - loss: 164.4680
# Epoch 28/100
#  - 0s - loss: 161.3792
# Epoch 29/100
#  - 0s - loss: 159.3757
# Epoch 30/100
#  - 0s - loss: 157.1272
# Epoch 31/100
#  - 0s - loss: 154.7707
# Epoch 32/100
#  - 0s - loss: 153.4463
# Epoch 33/100
#  - 0s - loss: 151.0490
# Epoch 34/100
#  - 0s - loss: 149.0561
# Epoch 35/100
#  - 0s - loss: 147.2875
# Epoch 36/100
#  - 0s - loss: 145.3941
# Epoch 37/100
#  - 0s - loss: 143.9309
# Epoch 38/100
#  - 0s - loss: 142.2395
# Epoch 39/100
#  - 0s - loss: 140.5516
# Epoch 40/100
#  - 0s - loss: 138.9000
# Epoch 41/100
#  - 0s - loss: 137.2533
# Epoch 42/100
#  - 0s - loss: 135.2850
# Epoch 43/100
#  - 0s - loss: 133.7001
# Epoch 44/100
#  - 0s - loss: 132.6091
# Epoch 45/100
#  - 0s - loss: 130.5557
# Epoch 46/100
#  - 0s - loss: 128.6550
# Epoch 47/100
#  - 0s - loss: 127.0468
# Epoch 48/100
#  - 0s - loss: 125.3694
# Epoch 49/100
#  - 0s - loss: 123.7972
# Epoch 50/100
#  - 0s - loss: 121.9025
# Epoch 51/100
#  - 0s - loss: 120.1176
# Epoch 52/100
#  - 0s - loss: 119.0186
# Epoch 53/100
#  - 0s - loss: 116.7784
# Epoch 54/100
#  - 0s - loss: 114.7573
# Epoch 55/100
#  - 0s - loss: 112.6612
# Epoch 56/100
#  - 0s - loss: 110.5640
# Epoch 57/100
#  - 0s - loss: 107.8881
# Epoch 58/100
#  - 0s - loss: 105.7286
# Epoch 59/100
#  - 0s - loss: 103.6979
# Epoch 60/100
#  - 0s - loss: 101.3676
# Epoch 61/100
#  - 0s - loss: 99.2334
# Epoch 62/100
#  - 0s - loss: 96.9655
# Epoch 63/100
#  - 0s - loss: 94.6641
# Epoch 64/100
#  - 0s - loss: 92.2630
# Epoch 65/100
#  - 0s - loss: 90.5093
# Epoch 66/100
#  - 0s - loss: 87.4765
# Epoch 67/100
#  - 0s - loss: 85.5219
# Epoch 68/100
#  - 0s - loss: 82.6090
# Epoch 69/100
#  - 0s - loss: 81.1536
# Epoch 70/100
#  - 0s - loss: 78.0867
# Epoch 71/100
#  - 0s - loss: 76.4537
# Epoch 72/100
#  - 0s - loss: 74.7220
# Epoch 73/100
#  - 0s - loss: 72.9143
# Epoch 74/100
#  - 0s - loss: 70.8116
# Epoch 75/100
#  - 0s - loss: 69.0801
# Epoch 76/100
#  - 0s - loss: 66.9379
# Epoch 77/100
#  - 0s - loss: 65.6989
# Epoch 78/100
#  - 0s - loss: 63.5103
# Epoch 79/100
#  - 0s - loss: 61.8973
# Epoch 80/100
#  - 0s - loss: 60.1962
# Epoch 81/100
#  - 0s - loss: 58.4588
# Epoch 82/100
#  - 0s - loss: 57.1821
# Epoch 83/100
#  - 0s - loss: 55.3956
# Epoch 84/100
#  - 0s - loss: 54.8781
# Epoch 85/100
#  - 0s - loss: 52.9290
# Epoch 86/100
#  - 0s - loss: 51.8778
# Epoch 87/100
#  - 0s - loss: 51.0463
# Epoch 88/100
#  - 0s - loss: 49.6189
# Epoch 89/100
#  - 0s - loss: 49.0934
# Epoch 90/100
#  - 0s - loss: 47.0753
# Epoch 91/100
#  - 0s - loss: 46.7712
# Epoch 92/100
#  - 0s - loss: 45.5990
# Epoch 93/100
#  - 0s - loss: 44.0330
# Epoch 94/100
#  - 0s - loss: 42.8832
# Epoch 95/100
#  - 0s - loss: 42.2670
# Epoch 96/100
#  - 0s - loss: 41.3496
# Epoch 97/100
#  - 0s - loss: 40.4875
# Epoch 98/100
#  - 0s - loss: 39.7017
# Epoch 99/100
#  - 0s - loss: 39.6651
# Epoch 100/100
#  - 0s - loss: 38.7618
# Executing op __inference_keras_scratch_graph_214906 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op __inference_keras_scratch_graph_214973 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op RandomUniform in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op RandomUniform in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op RandomUniform in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op RandomUniform in device /job:localhost/replica:0/task:0/device:GPU:0
# Epoch 1/100
# Executing op __inference_keras_scratch_graph_216063 in device /job:localhost/replica:0/task:0/device:GPU:0
#  - 0s - loss: 1572.5201
# Epoch 2/100
#  - 0s - loss: 1529.5807
# Epoch 3/100
#  - 0s - loss: 1470.7680
# Epoch 4/100
#  - 0s - loss: 1380.1471
# Epoch 5/100
#  - 0s - loss: 1247.9221
# Epoch 6/100
#  - 0s - loss: 1059.4688
# Epoch 7/100
#  - 0s - loss: 815.9390
# Epoch 8/100
#  - 0s - loss: 544.5011
# Epoch 9/100
#  - 0s - loss: 344.5112
# Epoch 10/100
#  - 0s - loss: 280.5108
# Epoch 11/100
#  - 0s - loss: 264.8259
# Epoch 12/100
#  - 0s - loss: 236.8242
# Epoch 13/100
#  - 0s - loss: 223.6927
# Epoch 14/100
#  - 0s - loss: 216.3609
# Epoch 15/100
#  - 0s - loss: 208.5258
# Epoch 16/100
#  - 0s - loss: 202.7826
# Epoch 17/100
#  - 0s - loss: 197.9527
# Epoch 18/100
#  - 0s - loss: 193.2016
# Epoch 19/100
#  - 0s - loss: 189.0071
# Epoch 20/100
#  - 0s - loss: 185.3892
# Epoch 21/100
#  - 0s - loss: 181.7486
# Epoch 22/100
#  - 0s - loss: 178.3255
# Epoch 23/100
#  - 0s - loss: 175.2347
# Epoch 24/100
#  - 0s - loss: 172.6571
# Epoch 25/100
#  - 0s - loss: 169.6984
# Epoch 26/100
#  - 0s - loss: 167.1242
# Epoch 27/100
#  - 0s - loss: 164.5970
# Epoch 28/100
#  - 0s - loss: 162.1009
# Epoch 29/100
#  - 0s - loss: 159.9306
# Epoch 30/100
#  - 0s - loss: 157.7693
# Epoch 31/100
#  - 0s - loss: 156.2021
# Epoch 32/100
#  - 0s - loss: 153.9169
# Epoch 33/100
#  - 0s - loss: 151.8874
# Epoch 34/100
#  - 0s - loss: 149.9215
# Epoch 35/100
#  - 0s - loss: 148.8227
# Epoch 36/100
#  - 0s - loss: 146.4779
# Epoch 37/100
#  - 0s - loss: 144.8894
# Epoch 38/100
#  - 0s - loss: 142.9193
# Epoch 39/100
#  - 0s - loss: 141.5729
# Epoch 40/100
#  - 0s - loss: 139.4964
# Epoch 41/100
#  - 0s - loss: 139.1667
# Epoch 42/100
#  - 0s - loss: 136.3971
# Epoch 43/100
#  - 0s - loss: 134.9672
# Epoch 44/100
#  - 0s - loss: 132.4122
# Epoch 45/100
#  - 0s - loss: 131.1360
# Epoch 46/100
#  - 0s - loss: 128.6880
# Epoch 47/100
#  - 0s - loss: 127.2329
# Epoch 48/100
#  - 0s - loss: 125.6139
# Epoch 49/100
#  - 0s - loss: 123.3824
# Epoch 50/100
#  - 0s - loss: 121.2221
# Epoch 51/100
#  - 0s - loss: 119.2602
# Epoch 52/100
#  - 0s - loss: 116.8194
# Epoch 53/100
#  - 0s - loss: 114.2530
# Epoch 54/100
#  - 0s - loss: 112.1606
# Epoch 55/100
#  - 0s - loss: 109.9085
# Epoch 56/100
#  - 0s - loss: 108.3276
# Epoch 57/100
#  - 0s - loss: 105.7360
# Epoch 58/100
#  - 0s - loss: 103.2803
# Epoch 59/100
#  - 0s - loss: 100.8194
# Epoch 60/100
#  - 0s - loss: 99.0243
# Epoch 61/100
#  - 0s - loss: 97.0118
# Epoch 62/100
#  - 0s - loss: 94.2651
# Epoch 63/100
#  - 0s - loss: 92.7753
# Epoch 64/100
#  - 0s - loss: 90.2205
# Epoch 65/100
#  - 0s - loss: 88.4270
# Epoch 66/100
#  - 0s - loss: 86.4181
# Epoch 67/100
#  - 0s - loss: 84.7822
# Epoch 68/100
#  - 0s - loss: 82.3826
# Epoch 69/100
#  - 0s - loss: 80.3673
# Epoch 70/100
#  - 0s - loss: 78.8355
# Epoch 71/100
#  - 0s - loss: 76.5641
# Epoch 72/100
#  - 0s - loss: 75.0138
# Epoch 73/100
#  - 0s - loss: 73.2804
# Epoch 74/100
#  - 0s - loss: 71.1357
# Epoch 75/100
#  - 0s - loss: 69.8319
# Epoch 76/100
#  - 0s - loss: 68.2444
# Epoch 77/100
#  - 0s - loss: 66.6401
# Epoch 78/100
#  - 0s - loss: 65.4573
# Epoch 79/100
#  - 0s - loss: 63.6588
# Epoch 80/100
#  - 0s - loss: 63.0514
# Epoch 81/100
#  - 0s - loss: 62.6485
# Epoch 82/100
#  - 0s - loss: 60.1847
# Epoch 83/100
#  - 0s - loss: 58.6310
# Epoch 84/100
#  - 0s - loss: 57.5505
# Epoch 85/100
#  - 0s - loss: 56.6677
# Epoch 86/100
#  - 0s - loss: 55.1541
# Epoch 87/100
#  - 0s - loss: 54.0867
# Epoch 88/100
#  - 0s - loss: 53.1302
# Epoch 89/100
#  - 0s - loss: 52.6827
# Epoch 90/100
#  - 0s - loss: 50.9663
# Epoch 91/100
#  - 0s - loss: 50.3587
# Epoch 92/100
#  - 0s - loss: 49.6811
# Epoch 93/100
#  - 0s - loss: 49.1331
# Epoch 94/100
#  - 0s - loss: 48.3612
# Epoch 95/100
#  - 0s - loss: 47.8571
# Epoch 96/100
#  - 0s - loss: 46.8448
# Epoch 97/100
#  - 0s - loss: 46.4055
# Epoch 98/100
#  - 0s - loss: 45.5881
# Epoch 99/100
#  - 0s - loss: 45.3279
# Epoch 100/100
#  - 0s - loss: 44.1881
# Executing op __inference_keras_scratch_graph_219294 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op __inference_keras_scratch_graph_219361 in device /job:localhost/replica:0/task:0/device:GPU:0

# %%
print(me_arran_squared_error_arr)
# Out:
# [64.12894692775888, 72.1737692749616, 73.60567711394967, 61.757212222201154, 62.1843252830135, 57.74450441625898, 67.74115617375544, 57.875853208276446, 52.22940091870749, 58.871931699487384, 74.08647081689926, 67.98035770403915, 57.10871926711987, 57.005124916150734, 70.96521749156965, 80.2151169267673, 52.105859787332975, 60.2490963241429, 67.06824685994862, 54.14473087347827, 61.07125273028624, 76.80136128150916, 57.55116992938094, 62.877160081585636, 80.68799936732813, 56.0275536077308, 57.99816932801676, 64.26285259160409, 59.918920918189976, 64.10795242655239, 75.0060280117788, 66.90197529221815, 83.31877533749083, 61.03772962749197, 97.62214692742307, 61.470896279541805, 62.10399222759753, 52.68389945662909, 59.47124040474012, 56.8738969722612, 58.52849252941539, 69.11776627228869, 61.31436023897338, 68.27280566761794, 53.11642161002051, 57.44291279616865, 59.675564096197725, 68.58849332247738, 64.90622224776877, 68.1828516741015]

# %%
import statistics
statistics.stdev(me_arran_squared_error_arr)
# Out:
# 8.998572032164487

# %%
print("Epoch count 100 The mean of tree hidden layers model is", round(statistics.mean(me_arran_squared_error_arr),1), "and the standard deviation is" , round(statistics.stdev(me_arran_squared_error_arr),1))
# Out:
# Epoch count 100 The mean of tree hidden layers model is 64.3 and the standard deviation is 9.0

# %% [markdown]
# Next, we will train and test the model at the same time using the *fit* method. We will leave out 30% of the data for validation and we will train the model for 100 epochs.

# %% [markdown]
# <strong>You can refer to this [link](https://keras.io/models/sequential/) to learn about other functions that you can use for prediction or evaluation.</strong>

# %% [markdown]
# Feel free to vary the following and note what impact each change has on the model's performance:
#
# 1. Increase or decreate number of neurons in hidden layers
# 2. Add more hidden layers
# 3. Increase number of epochs

# %% [markdown]
# ### Thank you for completing this lab!
#
# This notebook was created by [Alex Aklson](https://www.linkedin.com/in/aklson/). I hope you found this lab interesting and educational. Feel free to contact me if you have any questions!

# %% [markdown]
# This notebook is part of a course on **Coursera** called *Introduction to Deep Learning & Neural Networks with Keras*. If you accessed this notebook outside the course, you can take this course online by clicking [here](https://cocl.us/DL0101EN_Coursera_Week3_LAB1).

# %% [markdown]
# <hr>
#
# Copyright &copy; 2019 [IBM Developer Skills Network](https://cognitiveclass.ai/?utm_source=bducopyrightlink&utm_medium=dswb&utm_campaign=bdu). This notebook and its source code are released under the terms of the [MIT License](https://bigdatauniversity.com/mit-license/).
